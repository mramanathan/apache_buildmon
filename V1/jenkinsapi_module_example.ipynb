# %%
from jenkinsapi import api

apachePyApi = api.Jenkins('https://builds.apache.org/api/python')

dir(apachePyApi)
# Out:
# ['RETRY_ATTEMPTS',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_clone',
#  '_data',
#  '_poll',
#  '_poll_if_needed',
#  'base_server_url',
#  'baseurl',
#  'build_job',
#  'copy_job',
#  'create_job',
#  'create_node',
#  'credentials',
#  'delete_job',
#  'delete_node',
#  'delete_view_by_url',
#  'get_artifact_data',
#  'get_create_url',
#  'get_credentials',
#  'get_data',
#  'get_executors',
#  'get_jenkins_obj',
#  'get_jenkins_obj_from_url',
#  'get_job',
#  'get_jobs',
#  'get_jobs_info',
#  'get_jobs_list',
#  'get_master_data',
#  'get_node',
#  'get_node_url',
#  'get_nodes',
#  'get_nodes_url',
#  'get_plugins',
# ...

# %%
cldStk = apachePyApi.get_job('cloudstack-marvin')

dir(cldStk)
# Out:
# ['RETRY_ATTEMPTS',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_missing_builds',
#  '_buildid_for_type',
#  '_config',
#  '_data',
#  '_element_tree',
#  '_get_config_element_tree',
#  '_get_hg_branch',
#  '_mk_json_from_build_parameters',
#  '_poll',
#  '_revmap',
#  '_scm_map',
#  '_scmbranchmap',
#  '_scmurlmap',
#  'baseurl',
#  'delete_from_queue',
#  'disable',
#  'enable',
#  'get_build',
#  'get_build_dict',
#  'get_build_ids',
#  'get_build_metadata',
#  'get_build_triggerurl',
#  'get_buildnumber_for_revision',
#  'get_config',
#  'get_config_xml_url',
#  'get_data',
#  'get_delete_url',
#  'get_description',
#  'get_downstream_job_names',
# ...

# %%
print cldStk.get_last_good_build()
# Out:
# cloudstack-marvin #2454

# %%
print apachePyApi.get_jobs()
# Out:
# <generator object get_jobs at 0x7f18f87e2dc0>

# %%
for ijob in apachePyApi.get_jobs():
    print ijob
# Out:
# ('Abdera-trunk', <jenkinsapi.job.Job Abdera-trunk>)
# ('Abdera2-trunk', <jenkinsapi.job.Job Abdera2-trunk>)
# ('Accumulo-1.6', <jenkinsapi.job.Job Accumulo-1.6>)
# ('Accumulo-1.7', <jenkinsapi.job.Job Accumulo-1.7>)
# ('Accumulo-1.8', <jenkinsapi.job.Job Accumulo-1.8>)
# ('Accumulo-Master', <jenkinsapi.job.Job Accumulo-Master>)
# ('Accumulo-Pull-Requests', <jenkinsapi.job.Job Accumulo-Pull-Requests>)
# ('ACE-trunk', <jenkinsapi.job.Job ACE-trunk>)
# ('ActiveMQ Protocol Buffer', <jenkinsapi.job.Job ActiveMQ Protocol Buffer>)
# ('ActiveMQ-Apollo', <jenkinsapi.job.Job ActiveMQ-Apollo>)
# ('ActiveMQ-Apollo-Deploy', <jenkinsapi.job.Job ActiveMQ-Apollo-Deploy>)
# ('ActiveMQ-Artemis-Deploy', <jenkinsapi.job.Job ActiveMQ-Artemis-Deploy>)
# ('ActiveMQ-Artemis-Master', <jenkinsapi.job.Job ActiveMQ-Artemis-Master>)
# ('ActiveMQ-Artemis-Nightly-Regression-Test', <jenkinsapi.job.Job ActiveMQ-Artemis-Nightly-Regression-Test>)
# ...

# %%
dir(ijob)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
type(cldStk.get_build_dict())
# Out:
# dict

# %%
print cldStk.get_build_dict()
# Out:
# {2445: 'https://builds.apache.org/job/cloudstack-marvin/2445/', 2446: 'https://builds.apache.org/job/cloudstack-marvin/2446/', 2447: 'https://builds.apache.org/job/cloudstack-marvin/2447/', 2448: 'https://builds.apache.org/job/cloudstack-marvin/2448/', 2449: 'https://builds.apache.org/job/cloudstack-marvin/2449/', 2450: 'https://builds.apache.org/job/cloudstack-marvin/2450/', 2451: 'https://builds.apache.org/job/cloudstack-marvin/2451/', 2452: 'https://builds.apache.org/job/cloudstack-marvin/2452/', 2453: 'https://builds.apache.org/job/cloudstack-marvin/2453/', 2454: 'https://builds.apache.org/job/cloudstack-marvin/2454/'}

# %%
zkSol = apachePyApi.get_job("ZooKeeper_branch35_solaris")

print zkSol.get_build_ids()

# %%
for jk in zkSol.get_build_ids():
    print jk
# Out:
# 106
# 105
# 104
# 103
# 102
# 101
# 100
# 99
# 98
# 97
# 96
# 95
# 94
# 93
# 92
# 91
# 90
# 89
# 88
# 87
# 86
# 85
# 84
# 83
# 82
# 81
# 80
# 79
# 78
# 77
# 76
# 75
# 74
# 73
# 72
# 71
# 70
# 69
# 68
# 67
# 66
# 65
# 64
# 63
# 62
# 61
# 60
# 59
# 58

# %%
help(zkSol.get_build_metadata)
# Out:
# Help on method get_build_metadata in module jenkinsapi.job:
#
# get_build_metadata(self, buildnumber) method of jenkinsapi.job.Job instance
#     Get the build metadata for a given build number. For large builds with
#     tons of tests, this method is faster than get_build by returning less
#     data.

# %%
print zkSol.get_build_metadata(106)
# Out:
# ZooKeeper_branch35_solaris #106

# %%
zkSol_lastBuild = zkSol.get_last_build()

type(zkSol_lastBuild)

dir(zkSol_lastBuild)
# Out:
# ['RETRY_ATTEMPTS',
#  'STR_TOTALCOUNT',
#  'STR_TPL_NOTESTS_ERR',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_get_git_rev',
#  '_get_git_rev_branch',
#  '_get_hg_rev',
#  '_get_hg_rev_branch',
#  '_get_svn_rev',
#  '_get_svn_rev_branch',
#  '_poll',
#  'baseurl',
#  'block',
#  'block_until_complete',
#  'buildno',
#  'depth',
#  'get_actions',
#  'get_artifact_dict',
#  'get_artifacts',
#  'get_causes',
#  'get_changeset_items',
#  'get_console',
#  'get_data',
#  'get_description',
#  'get_downstream_builds',
#  'get_downstream_job_names',
#  'get_downstream_jobs',
#  'get_duration',
#  'get_jenkins_obj',
#  'get_master_build',
#  'get_master_build_number',
#  'get_master_job',
# ...

# %%
print zkSol_lastBuild.buildno
# Out:
# 106

# %%
print zkSol_lastBuild.baseurl
# Out:
# https://builds.apache.org/job/ZooKeeper_branch35_solaris/106

# %%
print zkSol_lastBuild.get_duration
print zkSol_lastBuild.get_duration()

help(zkSol_lastBuild.get_timestamp)

print zkSol_lastBuild.get_timestamp()
# Out:
# <bound method Build.get_duration of <jenkinsapi.build.Build ZooKeeper_branch35_solaris #106>>
# 1:10:55.536000
# Help on method get_timestamp in module jenkinsapi.build:
#
# get_timestamp(self) method of jenkinsapi.build.Build instance
#     Returns build timestamp in UTC
#
# 2016-05-21 16:05:04+00:00

# %%
print zkSol_lastBuild.get_status()
# Out:
# FAILURE

# %%
print zkSol_lastBuild.get_result_url()
# Out:
# https://builds.apache.org/job/ZooKeeper_branch35_solaris/106/testReport/api/python

# %%
print zkSol_lastBuild.is_good
# Out:
# <bound method Build.is_good of <jenkinsapi.build.Build ZooKeeper_branch35_solaris #106>>

# %%
print zkSol_lastBuild.is_good()
# Out:
# False

# %%
print zkSol_lastBuild.job
# Out:
# ZooKeeper_branch35_solaris

# %%
print zkSol_lastBuild.name
# Out:
# ZooKeeper_branch35_solaris #106

# %%
type(ijob)
# Out:
# tuple

# %%
print ijob
# Out:
# ('ZooKeeper_branch35_solaris', <jenkinsapi.job.Job ZooKeeper_branch35_solaris>)

# %%
help(ijob)
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple() -> empty tuple
#  |  tuple(iterable) -> tuple initialized from iterable's items
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getnewargs__(...)
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
#  |      Use of negative indices is not supported.
#  |
#  |  __gt__(...)
#  |      x.__gt__(y) <==> x>y
#  |
#  |  __hash__(...)
#  |      x.__hash__() <==> hash(x)
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __le__(...)
# ...

# %%
print ijob[0]
# Out:
# ZooKeeper_branch35_solaris

# %%
for lo in apachePyApi.get_jobs():
    print "Apache project : %s" %(lo[0])
# Out:
# Apache project : Abdera-trunk
# Apache project : Abdera2-trunk
# Apache project : Accumulo-1.6
# Apache project : Accumulo-1.7
# Apache project : Accumulo-1.8
# Apache project : Accumulo-Master
# Apache project : Accumulo-Pull-Requests
# Apache project : ACE-trunk
# Apache project : ActiveMQ Protocol Buffer
# Apache project : ActiveMQ-Apollo
# Apache project : ActiveMQ-Apollo-Deploy
# Apache project : ActiveMQ-Artemis-Deploy
# Apache project : ActiveMQ-Artemis-Master
# Apache project : ActiveMQ-Artemis-Nightly-Regression-Test
# Apache project : ActiveMQ-Artemis-PR-Build
# Apache project : ActiveMQ-Java7
# Apache project : ActiveMQ-Java7-All-UnitTests
# Apache project : ActiveMQ-Java8
# Apache project : ActiveMQ-LevelDB-Store
# Apache project : ActiveMQ-openwire
# Apache project : ActiveMQ-PR-Build
# Apache project : ActiveMQ-SysTest-Trunk
# Apache project : ActiveMQ-Trunk-Deploy
# Apache project : Airavata
# Apache project : Allura
# Apache project : Allura-rat
# ...
