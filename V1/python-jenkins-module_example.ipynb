# %%
""" Let's attempt with python-jenkins """
import jenkins

srvrJnkins = jenkins.Jenkins('https://builds.apache.org/job/cloudstack-marvin/')

# %%
print srvrJnkins.server
# Out:
# https://builds.apache.org/job/cloudstack-marvin/

# %%
cldStkInfo = srvrJnkins.get_info()

type(cldStkInfo)
# Out:
# dict

# %%
for o,p in cldStkInfo.iteritems():
    print o, p
# Out:
# scm {}
# color blue
# lastSuccessfulBuild {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2454/', u'number': 2454}
# actions [{}, {}, {}, None, {}]
# lastCompletedBuild {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2454/', u'number': 2454}
# lastUnsuccessfulBuild {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2453/', u'number': 2453}
# upstreamProjects [{u'url': u'https://builds.apache.org/job/cloudstack-apidocs-master/', u'color': u'blue', u'name': u'cloudstack-apidocs-master'}]
# lastFailedBuild {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2450/', u'number': 2450}
# healthReport [{u'iconUrl': u'health-60to79.png', u'score': 80, u'description': u'Build stability: 1 out of the last 5 builds failed.', u'iconClassName': u'icon-health-60to79'}]
# queueItem None
# lastBuild {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2454/', u'number': 2454}
# ...

# %%
print cldStkInfo['builds']
# Out:
# [{u'url': u'https://builds.apache.org/job/cloudstack-marvin/2454/', u'number': 2454}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2453/', u'number': 2453}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2452/', u'number': 2452}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2451/', u'number': 2451}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2450/', u'number': 2450}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2449/', u'number': 2449}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2448/', u'number': 2448}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2447/', u'number': 2447}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2446/', u'number': 2446}, {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2445/', u'number': 2445}]

# %%
print cldStkInfo['lastStableBuild']
# Out:
# {u'url': u'https://builds.apache.org/job/cloudstack-marvin/2454/', u'number': 2454}
