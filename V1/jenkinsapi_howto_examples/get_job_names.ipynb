# %%
"""
An example to show howto retrieve job names and 
details about individual jobs using Jenkinsapi.
"""

from jenkinsapi import api

jenJob = api.Jenkins('https://builds.apache.org/api/python')
jobName_1 = jenJob.keys()[0]
jobName_2 = jenJob.keys()[1]

### Section 1:
### ==========

print(jobName_1)
print(jobName_2)
# Out:
# Abdera-trunk
# Abdera2-trunk

# %% [markdown]
# #### Quick notes on section 1:
# **** ========================
# ###### Individual names are printed like:
# call_to_api_method.keys()[jobindex]

# %%
help(jenJob.jobs)
# Out:
# Help on Jobs in module jenkinsapi.jobs object:
#
# class Jobs(__builtin__.object)
#  |  This class provides a container-like API which gives
#  |  access to all jobs defined on the Jenkins server. It behaves
#  |  like a dict in which keys are Job-names and values are actual
#  |  jenkinsapi.Job objects.
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, job_name)
#  |      True if job_name is the name of a defined job
#  |
#  |  __delitem__(self, job_name)
#  |      Delete a job by name
#  |      :param job_name: name of a exist job, str
#  |
#  |  __getitem__(self, job_name)
#  |
#  |  __init__(self, jenkins)
#  |
#  |  __len__(self)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  build(self, job_name, params)
#  |
#  |  copy(self, job_name, new_job_name)
#  |      Copy a job
#  |      :param job_name: name of a exist job, str
#  |      :param new_job_name: name of new job, str
#  |      :return: new Job obj
#  |
#  |  create(self, job_name, config)
#  |      Create a job
#  |      :param jobname: name of new job, str
#  |      :param config: configuration of new job, xml
#  |      :return: new Job obj
#  |
#  |  iteritems(self)
#  |      Get the names & objects for all jobs
#  |
#  |  iterkeys(self)
#  |      Get the names of all available views
#  |
#  |  keys(self)
#  |      Return a list of the names of all jobs
#  |
#  |  rename(self, job_name, new_job_name)
#  |      Rename a job
#  |      :param job_name: name of a exist job, str
#  |      :param new_job_name: name of new job, str
#  |      :return: new Job obj
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(jenJob.jobs.keys)
# Out:
# Help on method keys in module jenkinsapi.jobs:
#
# keys(self) method of jenkinsapi.jobs.Jobs instance
#     Return a list of the names of all jobs

# %%
### Section 2:
### ==========
"""
Print all the jobs using the method keys() found in the class 
Jobs() that's part of 'jobs.py' in the jenkinsapi module.
"""

allJobs = jenJob.jobs.keys()
print("We will be evaluating build details of these projects hosted at Apache software foundation.")
print(allJobs)
# Out:
# We will be evaluating build details of these projects hosted at Apache software foundation.
# ['Abdera-trunk', 'Abdera2-trunk', 'Accumulo-1.6', 'Accumulo-1.7', 'Accumulo-1.8', 'Accumulo-Master', 'Accumulo-Pull-Requests', 'ACE-trunk', 'ActiveMQ Protocol Buffer', 'ActiveMQ-Apollo', 'ActiveMQ-Apollo-Deploy', 'ActiveMQ-Artemis-Deploy', 'ActiveMQ-Artemis-Master', 'ActiveMQ-Artemis-Nightly-Regression-Test', 'ActiveMQ-Artemis-PR-Build', 'ActiveMQ-Java7', 'ActiveMQ-Java7-All-UnitTests', 'ActiveMQ-Java8', 'ActiveMQ-LevelDB-Store', 'ActiveMQ-openwire', 'ActiveMQ-PR-Build', 'ActiveMQ-SysTest-Trunk', 'ActiveMQ-Trunk-Deploy', 'Airavata', 'Allura', 'Allura-rat', 'Ambari-branch-1.7.0', 'Ambari-branch-1.7.0-docker', 'Ambari-branch-2.0.0', 'Ambari-branch-2.1', 'Ambari-branch-2.2', 'Ambari-trunk-Commit', 'Ambari-trunk-Commit-debug', 'Ambari-trunk-Commit-docker', 'Ambari-trunk-find-patches-available', 'Ambari-trunk-test-patch', 'Ambari-view', 'Ant-Build-Matrix-1.9.x', 'Ant-Build-Matrix-master', 'ant-on-openjdk8', 'Ant_BuildFromPOMs', 'Ant_Nightly', 'AntLib-antunit', 'AntLib-common', 'AntLib-compress', 'AntLib-props', 'AntLib-svn', 'Any23-trunk', 'Apache Jackrabbit Oak Documentation', 'Apache Jackrabbit Oak matrix', 'apache-atlas-nightly', 'apache-deltacloud-core', 'Apache-falcon', 'Apache-Falcon-Distributed-Assembly', 'apache-falcon-nightly', 'apache-falcon-nightly-hadoop-2', 'apache-falcon-patch-build', 'Apache-Falcon-Pull-Request-Build', 'archiva-1.3.x', 'archiva-all-maven-3.x-with-web-it-js-windows', 'archiva-master-build', 'archiva-master-build-pr-builder', 'archiva-master-empty-repo', 'archiva-master-jdk-1.8', 'archiva-master-web-it-js', 'archiva-parent', 'archivW', 'Aries-Async-Deploy', 'Aries-Blueprint-JDK7', 'Aries-Deploy', 'Aries-JPA-Trunk-JDK7', 'Aries-JPA-Trunk-JDK7-Deploy', 'Aries-rsa master', 'Aries-rsa master deploy', 'Aries-Transaction-Trunk-JDK7', 'Aries-Trunk-JDK17', 'Aries-Tx-Control-Deploy', 'Aries-Tx-Control-Trunk-JDK8', 'AriesWithSnapshotDependencies', 'ASF Parent Pom', 'AsyncWeb', 'Aurora', 'aurora-packaging-nightly', 'AuroraBot', 'AVRO-python', 'AvroJava', 'AWF', 'axiom-1.2.x', 'axiom-experimental', 'axiom-trunk', 'axis-trunk', 'Axis2', 'axis2-1.6', 'axis2-1.7', 'batchee', 'beam_PostCommit_MavenVerify', 'beam_PostCommit_MavenVerify_NEW', 'beam_PostCommit_RunnableOnService_GoogleCloudDataflow', 'beam_PreCommit_MavenVerify', 'beam_PreCommit_RunnableOnService_GoogleCloudDataflow', 'beam_Release_NightlySnapshot', 'beam_Release_Prepare', 'beam_testing', 'Bigtop-Patch-Evaluate', 'Bigtop-tickle-slaves', 'Bigtop-trunk', 'Bigtop-trunk-iTest', 'Bigtop-trunk-test-execution', 'Bigtop-trunk-testartifacts', 'Blur-master-jdk8', 'bookkeeper-debug', 'bookkeeper-master', 'bookkeeper-master-find-patches-available', 'bookkeeper-master-git-pullrequest', 'bookkeeper-trunk-precommit-build', 'brooklyn-client-master', 'brooklyn-client-pull-requests', 'brooklyn-dist-master', 'brooklyn-dist-pull-requests', 'brooklyn-library-master', 'brooklyn-library-pull-requests', 'brooklyn-master-build', 'brooklyn-master-integration', 'brooklyn-master-windows', 'brooklyn-server-master', 'brooklyn-server-pull-requests', 'brooklyn-ui-master', 'brooklyn-ui-pull-requests', 'build-incubator-atlas', 'Buildr-ci-build-jruby-win32', 'BVal-trunk', 'BVal-trunk-linux-tck-deploy', 'Cactus', 'Calcite-Avatica-Master-JDK-1.7', 'Calcite-Avatica-Master-JDK-1.8', 'Calcite-Avatica-Test-JDK-1.7', 'Calcite-Master-JDK-1.7', 'Calcite-Master-JDK-1.8', 'Camel.2.15.x.fulltest', 'Camel.2.15.x.notest', 'Camel.2.16.x.fulltest', 'Camel.2.16.x.notest', 'Camel.2.17.x.fulltest', 'Camel.2.17.x.notest', 'Camel.trunk.fulltest.java8', 'Camel.trunk.itest.karaf', 'Camel.trunk.itest.osgi', 'Camel.trunk.notest', 'Cayenne pull requests', 'cayenne-30', 'cayenne-31', 'cayenne-master', 'central-indexer-test', 'Chemistry - DotCMIS', 'Chemistry - OpenCMIS - install - Java 6', 'Chemistry - OpenCMIS - install - Java 7', 'Chemistry - OpenCMIS - install - Java 8', 'Chemistry - OpenCMIS - javadoc', 'Chemistry - OpenCMIS - Release Profile', 'Chemistry - OpenCMIS - Workbench', 'Chemistry-Phyton-cmislib-doc',  ...

# %%
### Section 3:
### ==========
"""
Print all the jobs using the method get_jobs_info(), found in the 
class Jenkins() that's part of 'jenkins.py' in the jenkinsapi module.
"""

for info in jenJob.get_jobs_info():
    print(info[0], info[1])
# Out:
# https://builds.apache.org/job/Abdera-trunk/ Abdera-trunk
# https://builds.apache.org/job/Abdera2-trunk/ Abdera2-trunk
# https://builds.apache.org/job/Accumulo-1.6/ Accumulo-1.6
# https://builds.apache.org/job/Accumulo-1.7/ Accumulo-1.7
# https://builds.apache.org/job/Accumulo-1.8/ Accumulo-1.8
# https://builds.apache.org/job/Accumulo-Master/ Accumulo-Master
# https://builds.apache.org/job/Accumulo-Pull-Requests/ Accumulo-Pull-Requests
# https://builds.apache.org/job/ACE-trunk/ ACE-trunk
# https://builds.apache.org/job/ActiveMQ%20Protocol%20Buffer/ ActiveMQ Protocol Buffer
# https://builds.apache.org/job/ActiveMQ-Apollo/ ActiveMQ-Apollo
# https://builds.apache.org/job/ActiveMQ-Apollo-Deploy/ ActiveMQ-Apollo-Deploy
# https://builds.apache.org/job/ActiveMQ-Artemis-Deploy/ ActiveMQ-Artemis-Deploy
# https://builds.apache.org/job/ActiveMQ-Artemis-Master/ ActiveMQ-Artemis-Master
# https://builds.apache.org/job/ActiveMQ-Artemis-Nightly-Regression-Test/ ActiveMQ-Artemis-Nightly-Regression-Test
# https://builds.apache.org/job/ActiveMQ-Artemis-PR-Build/ ActiveMQ-Artemis-PR-Build
# https://builds.apache.org/job/ActiveMQ-Java7/ ActiveMQ-Java7
# https://builds.apache.org/job/ActiveMQ-Java7-All-UnitTests/ ActiveMQ-Java7-All-UnitTests
# https://builds.apache.org/job/ActiveMQ-Java8/ ActiveMQ-Java8
# https://builds.apache.org/job/ActiveMQ-LevelDB-Store/ ActiveMQ-LevelDB-Store
# https://builds.apache.org/job/ActiveMQ-openwire/ ActiveMQ-openwire
# https://builds.apache.org/job/ActiveMQ-PR-Build/ ActiveMQ-PR-Build
# https://builds.apache.org/job/ActiveMQ-SysTest-Trunk/ ActiveMQ-SysTest-Trunk
# https://builds.apache.org/job/ActiveMQ-Trunk-Deploy/ ActiveMQ-Trunk-Deploy
# https://builds.apache.org/job/Airavata/ Airavata
# https://builds.apache.org/job/Allura/ Allura
# https://builds.apache.org/job/Allura-rat/ Allura-rat
# https://builds.apache.org/job/Ambari-branch-1.7.0/ Ambari-branch-1.7.0
# https://builds.apache.org/job/Ambari-branch-1.7.0-docker/ Ambari-branch-1.7.0-docker
# https://builds.apache.org/job/Ambari-branch-2.0.0/ Ambari-branch-2.0.0
# https://builds.apache.org/job/Ambari-branch-2.1/ Ambari-branch-2.1
# https://builds.apache.org/job/Ambari-branch-2.2/ Ambari-branch-2.2
# https://builds.apache.org/job/Ambari-trunk-Commit/ Ambari-trunk-Commit
# https://builds.apache.org/job/Ambari-trunk-Commit-debug/ Ambari-trunk-Commit-debug
# https://builds.apache.org/job/Ambari-trunk-Commit-docker/ Ambari-trunk-Commit-docker
# https://builds.apache.org/job/Ambari-trunk-find-patches-available/ Ambari-trunk-find-patches-available
# https://builds.apache.org/job/Ambari-trunk-test-patch/ Ambari-trunk-test-patch
# https://builds.apache.org/job/Ambari-view/ Ambari-view
# https://builds.apache.org/job/Ant-Build-Matrix-1.9.x/ Ant-Build-Matrix-1.9.x
# https://builds.apache.org/job/Ant-Build-Matrix-master/ Ant-Build-Matrix-master
# https://builds.apache.org/job/ant-on-openjdk8/ ant-on-openjdk8
# https://builds.apache.org/job/Ant_BuildFromPOMs/ Ant_BuildFromPOMs
# https://builds.apache.org/job/Ant_Nightly/ Ant_Nightly
# https://builds.apache.org/job/AntLib-antunit/ AntLib-antunit
# https://builds.apache.org/job/AntLib-common/ AntLib-common
# https://builds.apache.org/job/AntLib-compress/ AntLib-compress
# https://builds.apache.org/job/AntLib-props/ AntLib-props
# https://builds.apache.org/job/AntLib-svn/ AntLib-svn
# https://builds.apache.org/job/Any23-trunk/ Any23-trunk
# https://builds.apache.org/job/Apache%20Jackrabbit%20Oak%20Documentation/ Apache Jackrabbit Oak Documentation
# https://builds.apache.org/job/Apache%20Jackrabbit%20Oak%20matrix/ Apache Jackrabbit Oak matrix
# https://builds.apache.org/job/apache-atlas-nightly/ apache-atlas-nightly
# https://builds.apache.org/job/apache-deltacloud-core/ apache-deltacloud-core
# https://builds.apache.org/job/Apache-falcon/ Apache-falcon
# https://builds.apache.org/job/Apache-Falcon-Distributed-Assembly/ Apache-Falcon-Distributed-Assembly
# https://builds.apache.org/job/apache-falcon-nightly/ apache-falcon-nightly
# https://builds.apache.org/job/apache-falcon-nightly-hadoop-2/ apache-falcon-nightly-hadoop-2
# https://builds.apache.org/job/apache-falcon-patch-build/ apache-falcon-patch-build
# https://builds.apache.org/job/Apache-Falcon-Pull-Request-Build/ Apache-Falcon-Pull-Request-Build
# https://builds.apache.org/job/archiva-1.3.x/ archiva-1.3.x
# https://builds.apache.org/job/archiva-all-maven-3.x-with-web-it-js-windows/ archiva-all-maven-3.x-with-web-it-js-windows
# https://builds.apache.org/job/archiva-master-build/ archiva-master-build
# https://builds.apache.org/job/archiva-master-build-pr-builder/ archiva-master-build-pr-builder
# https://builds.apache.org/job/archiva-master-empty-repo/ archiva-master-empty-repo
# https://builds.apache.org/job/archiva-master-jdk-1.8/ archiva-master-jdk-1.8
# https://builds.apache.org/job/archiva-master-web-it-js/ archiva-master-web-it-js
# https://builds.apache.org/job/archiva-parent/ archiva-parent
# https://builds.apache.org/job/archivW/ archivW
# https://builds.apache.org/job/Aries-Async-Deploy/ Aries-Async-Deploy
# https://builds.apache.org/job/Aries-Blueprint-JDK7/ Aries-Blueprint-JDK7
# https://builds.apache.org/job/Aries-Deploy/ Aries-Deploy
# https://builds.apache.org/job/Aries-JPA-Trunk-JDK7/ Aries-JPA-Trunk-JDK7
# https://builds.apache.org/job/Aries-JPA-Trunk-JDK7-Deploy/ Aries-JPA-Trunk-JDK7-Deploy
# https://builds.apache.org/job/Aries-rsa%20master/ Aries-rsa master
# https://builds.apache.org/job/Aries-rsa%20master%20deploy/ Aries-rsa master deploy
# https://builds.apache.org/job/Aries-Transaction-Trunk-JDK7/ Aries-Transaction-Trunk-JDK7
# https://builds.apache.org/job/Aries-Trunk-JDK17/ Aries-Trunk-JDK17
# https://builds.apache.org/job/Aries-Tx-Control-Deploy/ Aries-Tx-Control-Deploy
# https://builds.apache.org/job/Aries-Tx-Control-Trunk-JDK8/ Aries-Tx-Control-Trunk-JDK8
# https://builds.apache.org/job/AriesWithSnapshotDependencies/ AriesWithSnapshotDependencies
# https://builds.apache.org/job/ASF%20Parent%20Pom/ ASF Parent Pom
# https://builds.apache.org/job/AsyncWeb/ AsyncWeb
# https://builds.apache.org/job/Aurora/ Aurora
# https://builds.apache.org/job/aurora-packaging-nightly/ aurora-packaging-nightly
# https://builds.apache.org/job/AuroraBot/ AuroraBot
# https://builds.apache.org/job/AVRO-python/ AVRO-python
# https://builds.apache.org/job/AvroJava/ AvroJava
# https://builds.apache.org/job/AWF/ AWF
# https://builds.apache.org/job/axiom-1.2.x/ axiom-1.2.x
# https://builds.apache.org/job/axiom-experimental/ axiom-experimental
# https://builds.apache.org/job/axiom-trunk/ axiom-trunk
# https://builds.apache.org/job/axis-trunk/ axis-trunk
# https://builds.apache.org/job/Axis2/ Axis2
# https://builds.apache.org/job/axis2-1.6/ axis2-1.6
# https://builds.apache.org/job/axis2-1.7/ axis2-1.7
# https://builds.apache.org/job/batchee/ batchee
# https://builds.apache.org/job/beam_PostCommit_MavenVerify/ beam_PostCommit_MavenVerify
# https://builds.apache.org/job/beam_PostCommit_MavenVerify_NEW/ beam_PostCommit_MavenVerify_NEW
# https://builds.apache.org/job/beam_PostCommit_RunnableOnService_GoogleCloudDataflow/ beam_PostCommit_RunnableOnService_GoogleCloudDataflow
# https://builds.apache.org/job/beam_PreCommit_MavenVerify/ beam_PreCommit_MavenVerify
# https://builds.apache.org/job/beam_PreCommit_RunnableOnService_GoogleCloudDataflow/ beam_PreCommit_RunnableOnService_GoogleCloudDataflow
# https://builds.apache.org/job/beam_Release_NightlySnapshot/ beam_Release_NightlySnapshot
# https://builds.apache.org/job/beam_Release_Prepare/ beam_Release_Prepare
# https://builds.apache.org/job/beam_testing/ beam_testing
# https://builds.apache.org/job/Bigtop-Patch-Evaluate/ Bigtop-Patch-Evaluate
# https://builds.apache.org/job/Bigtop-tickle-slaves/ Bigtop-tickle-slaves
# https://builds.apache.org/job/Bigtop-trunk/ Bigtop-trunk
# https://builds.apache.org/job/Bigtop-trunk-iTest/ Bigtop-trunk-iTest
# https://builds.apache.org/job/Bigtop-trunk-test-execution/ Bigtop-trunk-test-execution
# https://builds.apache.org/job/Bigtop-trunk-testartifacts/ Bigtop-trunk-testartifacts
# https://builds.apache.org/job/Blur-master-jdk8/ Blur-master-jdk8
# https://builds.apache.org/job/bookkeeper-debug/ bookkeeper-debug
# https://builds.apache.org/job/bookkeeper-master/ bookkeeper-master
# https://builds.apache.org/job/bookkeeper-master-find-patches-available/ bookkeeper-master-find-patches-available
# https://builds.apache.org/job/bookkeeper-master-git-pullrequest/ bookkeeper-master-git-pullrequest
# https://builds.apache.org/job/bookkeeper-trunk-precommit-build/ bookkeeper-trunk-precommit-build
# https://builds.apache.org/job/brooklyn-client-master/ brooklyn-client-master
# https://builds.apache.org/job/brooklyn-client-pull-requests/ brooklyn-client-pull-requests
# https://builds.apache.org/job/brooklyn-dist-master/ brooklyn-dist-master
# https://builds.apache.org/job/brooklyn-dist-pull-requests/ brooklyn-dist-pull-requests
# https://builds.apache.org/job/brooklyn-library-master/ brooklyn-library-master
# https://builds.apache.org/job/brooklyn-library-pull-requests/ brooklyn-library-pull-requests
# https://builds.apache.org/job/brooklyn-master-build/ brooklyn-master-build
# https://builds.apache.org/job/brooklyn-master-integration/ brooklyn-master-integration
# https://builds.apache.org/job/brooklyn-master-windows/ brooklyn-master-windows
# https://builds.apache.org/job/brooklyn-server-master/ brooklyn-server-master
# https://builds.apache.org/job/brooklyn-server-pull-requests/ brooklyn-server-pull-requests
# https://builds.apache.org/job/brooklyn-ui-master/ brooklyn-ui-master
# https://builds.apache.org/job/brooklyn-ui-pull-requests/ brooklyn-ui-pull-requests
# https://builds.apache.org/job/build-incubator-atlas/ build-incubator-atlas
# https://builds.apache.org/job/Buildr-ci-build-jruby-win32/ Buildr-ci-build-jruby-win32
# https://builds.apache.org/job/BVal-trunk/ BVal-trunk
# https://builds.apache.org/job/BVal-trunk-linux-tck-deploy/ BVal-trunk-linux-tck-deploy
# https://builds.apache.org/job/Cactus/ Cactus
# https://builds.apache.org/job/Calcite-Avatica-Master-JDK-1.7/ Calcite-Avatica-Master-JDK-1.7
# https://builds.apache.org/job/Calcite-Avatica-Master-JDK-1.8/ Calcite-Avatica-Master-JDK-1.8
# https://builds.apache.org/job/Calcite-Avatica-Test-JDK-1.7/ Calcite-Avatica-Test-JDK-1.7
# https://builds.apache.org/job/Calcite-Master-JDK-1.7/ Calcite-Master-JDK-1.7
# https://builds.apache.org/job/Calcite-Master-JDK-1.8/ Calcite-Master-JDK-1.8
# https://builds.apache.org/job/Camel.2.15.x.fulltest/ Camel.2.15.x.fulltest
# https://builds.apache.org/job/Camel.2.15.x.notest/ Camel.2.15.x.notest
# https://builds.apache.org/job/Camel.2.16.x.fulltest/ Camel.2.16.x.fulltest
# https://builds.apache.org/job/Camel.2.16.x.notest/ Camel.2.16.x.notest
# https://builds.apache.org/job/Camel.2.17.x.fulltest/ Camel.2.17.x.fulltest
# https://builds.apache.org/job/Camel.2.17.x.notest/ Camel.2.17.x.notest
# https://builds.apache.org/job/Camel.trunk.fulltest.java8/ Camel.trunk.fulltest.java8
# https://builds.apache.org/job/Camel.trunk.itest.karaf/ Camel.trunk.itest.karaf
# https://builds.apache.org/job/Camel.trunk.itest.osgi/ Camel.trunk.itest.osgi
# https://builds.apache.org/job/Camel.trunk.notest/ Camel.trunk.notest
# https://builds.apache.org/job/Cayenne%20pull%20requests/ Cayenne pull requests
# https://builds.apache.org/job/cayenne-30/ cayenne-30
# https://builds.apache.org/job/cayenne-31/ cayenne-31
# https://builds.apache.org/job/cayenne-master/ cayenne-master
# https://builds.apache.org/job/central-indexer-test/ central-indexer-test
# https://builds.apache.org/job/Chemistry%20-%20DotCMIS/ Chemistry - DotCMIS
# https://builds.apache.org/job/Chemistry%20-%20OpenCMIS%20-%20install%20-%20Java%206/ Chemistry - OpenCMIS - install - Java 6
# https://builds.apache.org/job/Chemistry%20-%20OpenCMIS%20-%20install%20-%20Java%207/ Chemistry - OpenCMIS - install - Java 7
# https://builds.apache.org/job/Chemistry%20-%20OpenCMIS%20-%20install%20-%20Java%208/ Chemistry - OpenCMIS - install - Java 8
# https://builds.apache.org/job/Chemistry%20-%20OpenCMIS%20-%20javadoc/ Chemistry - OpenCMIS - javadoc
# https://builds.apache.org/job/Chemistry%20-%20OpenCMIS%20-%20Release%20Profile/ Chemistry - OpenCMIS - Release Profile
# https://builds.apache.org/job/Chemistry%20-%20OpenCMIS%20-%20Workbench/ Chemistry - OpenCMIS - Workbench
# https://builds.apache.org/job/Chemistry-Phyton-cmislib-doc/ Chemistry-Phyton-cmislib-doc
# https://builds.apache.org/job/Chukwa-master/ Chukwa-master
# https://builds.apache.org/job/clerezza/ clerezza
# https://builds.apache.org/job/clerezza-rdf-core/ clerezza-rdf-core
# https://builds.apache.org/job/clerezza-scala-1.6/ clerezza-scala-1.6
# https://builds.apache.org/job/clerezza-site/ clerezza-site
# https://builds.apache.org/job/climate_master_build/ climate_master_build
# https://builds.apache.org/job/cloudstack-apidocs-master/ cloudstack-apidocs-master
# https://builds.apache.org/job/cloudstack-marvin/ cloudstack-marvin
# https://builds.apache.org/job/cloudstack-master-maven/ cloudstack-master-maven
# https://builds.apache.org/job/cloudstack-pr-analysis/ cloudstack-pr-analysis
# https://builds.apache.org/job/cloudstack-rat-master/ cloudstack-rat-master
# https://builds.apache.org/job/cloudstack-simulator-master/ cloudstack-simulator-master
# https://builds.apache.org/job/cloudstack-simulator-singlerun/ cloudstack-simulator-singlerun
# https://builds.apache.org/job/Cocoon%202.1.X/ Cocoon 2.1.X
# https://builds.apache.org/job/Cocoon%202.2/ Cocoon 2.2
# https://builds.apache.org/job/Cocoon%203.0/ Cocoon 3.0
# https://builds.apache.org/job/CODI%20(add-ons)/ CODI (add-ons)
# https://builds.apache.org/job/CODI%20(deploy)/ CODI (deploy)
# https://builds.apache.org/job/CODI%20(nightly)/ CODI (nightly)
# https://builds.apache.org/job/CODI%20(nightly)%20-j%20ava8arm/ CODI (nightly) -j ava8arm
# https://builds.apache.org/job/codi-apache-extras/ codi-apache-extras
# https://builds.apache.org/job/codi-apache-extras-addons/ codi-apache-extras-addons
# https://builds.apache.org/job/codi-apache-extras-test/ codi-apache-extras-test
# https://builds.apache.org/job/codi-mirror/ codi-mirror
# https://builds.apache.org/job/CODI-test/ CODI-test
# https://builds.apache.org/job/CODI-u1test/ CODI-u1test
# https://builds.apache.org/job/Commons%20Math%20DeveloperBranch/ Commons Math DeveloperBranch
# https://builds.apache.org/job/Commons%20Math%20MasterBranch/ Commons Math MasterBranch
# https://builds.apache.org/job/Commons%20Test%20-%20do%20not%20use/ Commons Test - do not use
# https://builds.apache.org/job/Commons-Codec/ Commons-Codec
# https://builds.apache.org/job/commons-collections/ commons-collections
# https://builds.apache.org/job/Commons-Compress/ Commons-Compress
# https://builds.apache.org/job/Commons-Compress-Windows/ Commons-Compress-Windows
# https://builds.apache.org/job/Commons-configuration/ Commons-configuration
# https://builds.apache.org/job/Commons-CRYPTO-JDK1.6/ Commons-CRYPTO-JDK1.6
# https://builds.apache.org/job/Commons-CRYPTO-JDK1.7/ Commons-CRYPTO-JDK1.7
# https://builds.apache.org/job/Commons-CRYPTO-JDK1.8/ Commons-CRYPTO-JDK1.8
# https://builds.apache.org/job/commons-csv/ commons-csv
# https://builds.apache.org/job/Commons-FileUpload/ Commons-FileUpload
# https://builds.apache.org/job/commons-jcs/ commons-jcs
# https://builds.apache.org/job/Commons-Lang/ Commons-Lang
# https://builds.apache.org/job/Commons-ognl/ Commons-ognl
# https://builds.apache.org/job/commons-vfs-trunk/ commons-vfs-trunk
# https://builds.apache.org/job/CommonsAdHoc/ CommonsAdHoc
# https://builds.apache.org/job/CommonsAnt/ CommonsAnt
# https://builds.apache.org/job/cordova-nightly/ cordova-nightly
# https://builds.apache.org/job/cordova-nightly-test/ cordova-nightly-test
# https://builds.apache.org/job/core-integration-testing-maven-3/ core-integration-testing-maven-3
# https://builds.apache.org/job/core-integration-testing-maven-3-embedded/ core-integration-testing-maven-3-embedded
# https://builds.apache.org/job/core-integration-testing-maven-3-jdk-1.6-windows/ core-integration-testing-maven-3-jdk-1.6-windows
# https://builds.apache.org/job/core-integration-testing-maven-3-jdk-1.7/ core-integration-testing-maven-3-jdk-1.7
# https://builds.apache.org/job/core-integration-testing-maven-3-jdk-1.8/ core-integration-testing-maven-3-jdk-1.8
# https://builds.apache.org/job/core-integration-testing-maven-3-osx/ core-integration-testing-maven-3-osx
# https://builds.apache.org/job/core-integration-testing-maven-3-solaris/ core-integration-testing-maven-3-solaris
# https://builds.apache.org/job/core-it-maven-3-win/ core-it-maven-3-win
# https://builds.apache.org/job/CouchDB/ CouchDB
# https://builds.apache.org/job/Creadur-Rat/ Creadur-Rat
# https://builds.apache.org/job/Creadur-Rat-Latest-Jdk/ Creadur-Rat-Latest-Jdk
# https://builds.apache.org/job/Creadur-Rat-ParentPom/ Creadur-Rat-ParentPom
# https://builds.apache.org/job/Creadur-Rat-Site/ Creadur-Rat-Site
# https://builds.apache.org/job/Creadur-Rat-Site-Latest-Jdk/ Creadur-Rat-Site-Latest-Jdk
# https://builds.apache.org/job/Creadur-Tentacles/ Creadur-Tentacles
# https://builds.apache.org/job/Creadur-Tentacles-Site/ Creadur-Tentacles-Site
# https://builds.apache.org/job/Creadur-Whisker/ Creadur-Whisker
# https://builds.apache.org/job/Creadur-Whisker-Latest-Jdk/ Creadur-Whisker-Latest-Jdk
# https://builds.apache.org/job/Creadur-Whisker-ParentPom/ Creadur-Whisker-ParentPom
# https://builds.apache.org/job/Creadur-Whisker-Site/ Creadur-Whisker-Site
# https://builds.apache.org/job/Creadur-Whisker-Site-Latest-Jdk/ Creadur-Whisker-Site-Latest-Jdk
# https://builds.apache.org/job/crunch-commit/ crunch-commit
# https://builds.apache.org/job/crunch-integration/ crunch-integration
# https://builds.apache.org/job/crunch-master/ crunch-master
# https://builds.apache.org/job/ctakes-trunk-compiletest/ ctakes-trunk-compiletest
# https://builds.apache.org/job/ctakes-trunk-package/ ctakes-trunk-package
# https://builds.apache.org/job/Curator/ Curator
# https://builds.apache.org/job/Curator-3.0/ Curator-3.0
# https://builds.apache.org/job/CXF-2.7-deploy/ CXF-2.7-deploy
# https://builds.apache.org/job/CXF-2.7.x/ CXF-2.7.x
# https://builds.apache.org/job/CXF-3.0-deploy/ CXF-3.0-deploy
# https://builds.apache.org/job/CXF-3.0.x/ CXF-3.0.x
# https://builds.apache.org/job/CXF-3.1-deploy/ CXF-3.1-deploy
# https://builds.apache.org/job/CXF-3.1.x/ CXF-3.1.x
# https://builds.apache.org/job/CXF-build-tools/ CXF-build-tools
# https://builds.apache.org/job/CXF-DOSGi/ CXF-DOSGi
# https://builds.apache.org/job/CXF-DOSGi-deploy/ CXF-DOSGi-deploy
# https://builds.apache.org/job/CXF-Fediz/ CXF-Fediz
# https://builds.apache.org/job/CXF-Fediz-1.2.x-fixes/ CXF-Fediz-1.2.x-fixes
# https://builds.apache.org/job/CXF-Fediz-openjdk17/ CXF-Fediz-openjdk17
# https://builds.apache.org/job/CXF-trunk-deploy/ CXF-trunk-deploy
# https://builds.apache.org/job/CXF-Trunk-JDK18/ CXF-Trunk-JDK18
# https://builds.apache.org/job/CXF-Trunk-PR/ CXF-Trunk-PR
# https://builds.apache.org/job/CXF-trunk-windows/ CXF-trunk-windows
# https://builds.apache.org/job/CXF-xjc-utils/ CXF-xjc-utils
# https://builds.apache.org/job/DeltaSpike%20Deploy/ DeltaSpike Deploy
# https://builds.apache.org/job/DeltaSpike%20Examples/ DeltaSpike Examples
# https://builds.apache.org/job/DeltaSpike%20for%20CDI%201.0/ DeltaSpike for CDI 1.0
# https://builds.apache.org/job/DeltaSpike%20for%20CDI%201.1%20and%201.2/ DeltaSpike for CDI 1.1 and 1.2
# https://builds.apache.org/job/DeltaSpike%20for%20CDI%202.0/ DeltaSpike for CDI 2.0
# https://builds.apache.org/job/DeltaSpike%20for%20Java%20EE/ DeltaSpike for Java EE
# https://builds.apache.org/job/DeltaSpike%20OWB%20(nightly)/ DeltaSpike OWB (nightly)
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.1/ DeltaSpike OWB 1.1.1
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.2/ DeltaSpike OWB 1.1.2
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.3/ DeltaSpike OWB 1.1.3
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.4/ DeltaSpike OWB 1.1.4
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.5/ DeltaSpike OWB 1.1.5
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.6/ DeltaSpike OWB 1.1.6
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.6%20(JDK%201.7)/ DeltaSpike OWB 1.1.6 (JDK 1.7)
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.7/ DeltaSpike OWB 1.1.7
# https://builds.apache.org/job/DeltaSpike%20OWB%201.1.8/ DeltaSpike OWB 1.1.8
# https://builds.apache.org/job/Deltaspike%20OWB%201.1.9-SNAPSHOT/ Deltaspike OWB 1.1.9-SNAPSHOT
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.0/ DeltaSpike OWB 1.2.0
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.1/ DeltaSpike OWB 1.2.1
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.1%20java8_ARM/ DeltaSpike OWB 1.2.1 java8_ARM
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.2/ DeltaSpike OWB 1.2.2
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.3/ DeltaSpike OWB 1.2.3
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.4/ DeltaSpike OWB 1.2.4
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.5/ DeltaSpike OWB 1.2.5
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.6/ DeltaSpike OWB 1.2.6
# https://builds.apache.org/job/DeltaSpike%20OWB%201.2.7/ DeltaSpike OWB 1.2.7
# https://builds.apache.org/job/DeltaSpike%20OWB%201.6.0/ DeltaSpike OWB 1.6.0
# https://builds.apache.org/job/DeltaSpike%20OWB%201.6.1/ DeltaSpike OWB 1.6.1
# https://builds.apache.org/job/DeltaSpike%20OWB%201.6.2/ DeltaSpike OWB 1.6.2
# https://builds.apache.org/job/DeltaSpike%20OWB%20JDK8/ DeltaSpike OWB JDK8
# https://builds.apache.org/job/DeltaSpike%20OWB%20OpenJDK8/ DeltaSpike OWB OpenJDK8
# https://builds.apache.org/job/DeltaSpike%20RAT-Check/ DeltaSpike RAT-Check
# https://builds.apache.org/job/DeltaSpike%20Weld%20(nightly)/ DeltaSpike Weld (nightly)
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.10/ DeltaSpike Weld 1.1.10
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.11/ DeltaSpike Weld 1.1.11
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.12/ DeltaSpike Weld 1.1.12
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.13/ DeltaSpike Weld 1.1.13
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.14/ DeltaSpike Weld 1.1.14
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.15/ DeltaSpike Weld 1.1.15
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.16/ DeltaSpike Weld 1.1.16
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.17/ DeltaSpike Weld 1.1.17
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.18/ DeltaSpike Weld 1.1.18
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.19/ DeltaSpike Weld 1.1.19
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.19%20(JDK%201.7)/ DeltaSpike Weld 1.1.19 (JDK 1.7)
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.20/ DeltaSpike Weld 1.1.20
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.21/ DeltaSpike Weld 1.1.21
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.22/ DeltaSpike Weld 1.1.22
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.23/ DeltaSpike Weld 1.1.23
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.24/ DeltaSpike Weld 1.1.24
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.25/ DeltaSpike Weld 1.1.25
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.26/ DeltaSpike Weld 1.1.26
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.27/ DeltaSpike Weld 1.1.27
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.28/ DeltaSpike Weld 1.1.28
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.29/ DeltaSpike Weld 1.1.29
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.3/ DeltaSpike Weld 1.1.3
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.3.SP1/ DeltaSpike Weld 1.1.3.SP1
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.30/ DeltaSpike Weld 1.1.30
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.31/ DeltaSpike Weld 1.1.31
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.32/ DeltaSpike Weld 1.1.32
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.33/ DeltaSpike Weld 1.1.33
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.4/ DeltaSpike Weld 1.1.4
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.5/ DeltaSpike Weld 1.1.5
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.5.AS71/ DeltaSpike Weld 1.1.5.AS71
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.6/ DeltaSpike Weld 1.1.6
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.7/ DeltaSpike Weld 1.1.7
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.8/ DeltaSpike Weld 1.1.8
# https://builds.apache.org/job/DeltaSpike%20Weld%201.1.9/ DeltaSpike Weld 1.1.9
# https://builds.apache.org/job/DeltaSpike%20Weld%202.0.0/ DeltaSpike Weld 2.0.0
# https://builds.apache.org/job/DeltaSpike%20Weld%202.0.0.SP1/ DeltaSpike Weld 2.0.0.SP1
# https://builds.apache.org/job/DeltaSpike%20Weld%202.0.1/ DeltaSpike Weld 2.0.1
# https://builds.apache.org/job/DeltaSpike%20Weld%202.0.2/ DeltaSpike Weld 2.0.2
# https://builds.apache.org/job/DeltaSpike%20Weld%202.0.3/ DeltaSpike Weld 2.0.3
# https://builds.apache.org/job/DeltaSpike%20Weld%202.0.4/ DeltaSpike Weld 2.0.4
# https://builds.apache.org/job/DeltaSpike%20Weld%202.0.5/ DeltaSpike Weld 2.0.5
# https://builds.apache.org/job/DeltaSpike%20Weld%202.1.0/ DeltaSpike Weld 2.1.0
# https://builds.apache.org/job/DeltaSpike%20Weld%202.1.1/ DeltaSpike Weld 2.1.1
# https://builds.apache.org/job/DeltaSpike%20Weld%202.1.2/ DeltaSpike Weld 2.1.2
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.0/ DeltaSpike Weld 2.2.0
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.1/ DeltaSpike Weld 2.2.1
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.10/ DeltaSpike Weld 2.2.10
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.10.SP1/ DeltaSpike Weld 2.2.10.SP1
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.11/ DeltaSpike Weld 2.2.11
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.12/ DeltaSpike Weld 2.2.12
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.13/ DeltaSpike Weld 2.2.13
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.14/ DeltaSpike Weld 2.2.14
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.15/ DeltaSpike Weld 2.2.15
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.16/ DeltaSpike Weld 2.2.16
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.16.SP1/ DeltaSpike Weld 2.2.16.SP1
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.2/ DeltaSpike Weld 2.2.2
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.3/ DeltaSpike Weld 2.2.3
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.4/ DeltaSpike Weld 2.2.4
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.5/ DeltaSpike Weld 2.2.5
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.6/ DeltaSpike Weld 2.2.6
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.7/ DeltaSpike Weld 2.2.7
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.8/ DeltaSpike Weld 2.2.8
# https://builds.apache.org/job/DeltaSpike%20Weld%202.2.9/ DeltaSpike Weld 2.2.9
# https://builds.apache.org/job/DeltaSpike%20Weld%202.3.0/ DeltaSpike Weld 2.3.0
# https://builds.apache.org/job/DeltaSpike%20Weld%202.3.1/ DeltaSpike Weld 2.3.1
# https://builds.apache.org/job/DeltaSpike%20Weld%202.3.2/ DeltaSpike Weld 2.3.2
# https://builds.apache.org/job/DeltaSpike%20Weld%202.3.3/ DeltaSpike Weld 2.3.3
# https://builds.apache.org/job/DeltaSpike%20Weld%202.3.4/ DeltaSpike Weld 2.3.4
# https://builds.apache.org/job/DeltaSpike%20Weld%203.0.0%20Alpha%2014/ DeltaSpike Weld 3.0.0 Alpha 14
# https://builds.apache.org/job/DeltaSpike_AS7/ DeltaSpike_AS7
# https://builds.apache.org/job/DeltaSpike_GF3/ DeltaSpike_GF3
# https://builds.apache.org/job/DeltaSpike_GF4/ DeltaSpike_GF4
# https://builds.apache.org/job/DeltaSpike_GF4.1/ DeltaSpike_GF4.1
# https://builds.apache.org/job/DeltaSpike_GF4.1.1/ DeltaSpike_GF4.1.1
# https://builds.apache.org/job/DeltaSpike_TomEE/ DeltaSpike_TomEE
# https://builds.apache.org/job/DeltaSpike_TomEE-SNAPSHOT/ DeltaSpike_TomEE-SNAPSHOT
# https://builds.apache.org/job/DeltaSpike_TomEE_1.6.0/ DeltaSpike_TomEE_1.6.0
# https://builds.apache.org/job/DeltaSpike_TomEE_1.7.0/ DeltaSpike_TomEE_1.7.0
# https://builds.apache.org/job/DeltaSpike_TomEE_1.7.1/ DeltaSpike_TomEE_1.7.1
# https://builds.apache.org/job/DeltaSpike_TomEE_1.7.2/ DeltaSpike_TomEE_1.7.2
# https://builds.apache.org/job/DeltaSpike_TomEE_1.7.3/ DeltaSpike_TomEE_1.7.3
# https://builds.apache.org/job/DeltaSpike_TomEE_7.0.0-M3/ DeltaSpike_TomEE_7.0.0-M3
# https://builds.apache.org/job/DeltaSpike_Wildfly/ DeltaSpike_Wildfly
# https://builds.apache.org/job/DeltaSpike_Wildfly_10/ DeltaSpike_Wildfly_10
# https://builds.apache.org/job/DeltaSpike_Wildfly_8.1/ DeltaSpike_Wildfly_8.1
# https://builds.apache.org/job/DeltaSpike_Wildfly_8.2/ DeltaSpike_Wildfly_8.2
# https://builds.apache.org/job/DeltaSpike_Wildfly_8.2.1/ DeltaSpike_Wildfly_8.2.1
# https://builds.apache.org/job/DeltaSpike_Wildfly_9.0/ DeltaSpike_Wildfly_9.0
# https://builds.apache.org/job/DeltaSpike_Wildfly_9.0.1/ DeltaSpike_Wildfly_9.0.1
# https://builds.apache.org/job/DeltaSpike_Wildfly_9.0.2/ DeltaSpike_Wildfly_9.0.2
# https://builds.apache.org/job/Derby-10.10-derbyall/ Derby-10.10-derbyall
# https://builds.apache.org/job/Derby-10.10-suites.All/ Derby-10.10-suites.All
# https://builds.apache.org/job/Derby-10.11-derbyall/ Derby-10.11-derbyall
# https://builds.apache.org/job/Derby-10.11-suites.All/ Derby-10.11-suites.All
# https://builds.apache.org/job/Derby-10.12-suites.All/ Derby-10.12-suites.All
# https://builds.apache.org/job/Derby-10.9-derbyall/ Derby-10.9-derbyall
# https://builds.apache.org/job/Derby-10.9-suites.All/ Derby-10.9-suites.All
# https://builds.apache.org/job/Derby-branch-10.10/ Derby-branch-10.10
# https://builds.apache.org/job/Derby-branch-10.11/ Derby-branch-10.11
# https://builds.apache.org/job/Derby-branch-10.12/ Derby-branch-10.12
# https://builds.apache.org/job/Derby-branch-10.5/ Derby-branch-10.5
# https://builds.apache.org/job/Derby-branch-10.6/ Derby-branch-10.6
# https://builds.apache.org/job/Derby-branch-10.7/ Derby-branch-10.7
# https://builds.apache.org/job/Derby-branch-10.8/ Derby-branch-10.8
# https://builds.apache.org/job/Derby-branch-10.9/ Derby-branch-10.9
# https://builds.apache.org/job/Derby-docs/ Derby-docs
# https://builds.apache.org/job/Derby-JaCoCo/ Derby-JaCoCo
# https://builds.apache.org/job/Derby-trunk/ Derby-trunk
# https://builds.apache.org/job/Derby-trunk-JaCoCo/ Derby-trunk-JaCoCo
# https://builds.apache.org/job/Derby-trunk-suites.All/ Derby-trunk-suites.All
# https://builds.apache.org/job/Derby-trunk-suites.All-ARM/ Derby-trunk-suites.All-ARM
# https://builds.apache.org/job/devicemap-browsermap/ devicemap-browsermap
# https://builds.apache.org/job/devicemap-data-1.0/ devicemap-data-1.0
# https://builds.apache.org/job/devicemap-java-client-1.0/ devicemap-java-client-1.0
# https://builds.apache.org/job/dir-apacheds-docker-installers/ dir-apacheds-docker-installers
# https://builds.apache.org/job/dir-apacheds-jdbm-ubuntu-deploy/ dir-apacheds-jdbm-ubuntu-deploy
# https://builds.apache.org/job/dir-apacheds-jdbm-win/ dir-apacheds-jdbm-win
# https://builds.apache.org/job/dir-apacheds-ubuntu-deploy/ dir-apacheds-ubuntu-deploy
# https://builds.apache.org/job/dir-apacheds-win/ dir-apacheds-win
# https://builds.apache.org/job/dir-checkstyle-deploy/ dir-checkstyle-deploy
# https://builds.apache.org/job/dir-fortress-core-docker-test/ dir-fortress-core-docker-test
# https://builds.apache.org/job/dir-groovyldap-deploy/ dir-groovyldap-deploy
# https://builds.apache.org/job/dir-junit-addons-deploy/ dir-junit-addons-deploy
# https://builds.apache.org/job/dir-kerby/ dir-kerby
# https://builds.apache.org/job/dir-kerby-openjdk/ dir-kerby-openjdk
# https://builds.apache.org/job/dir-mavibot-ubuntu-deploy/ dir-mavibot-ubuntu-deploy
# https://builds.apache.org/job/dir-mavibot-win/ dir-mavibot-win
# https://builds.apache.org/job/dir-project-deploy/ dir-project-deploy
# https://builds.apache.org/job/dir-shared-ubuntu-deploy/ dir-shared-ubuntu-deploy
# https://builds.apache.org/job/dir-shared-win/ dir-shared-win
# https://builds.apache.org/job/dir-skins-deploy/ dir-skins-deploy
# https://builds.apache.org/job/dir-studio/ dir-studio
# https://builds.apache.org/job/dir-studio-ui-tests/ dir-studio-ui-tests
# https://builds.apache.org/job/dist-tool-plugin/ dist-tool-plugin
# https://builds.apache.org/job/doxia/ doxia
# https://builds.apache.org/job/doxia-all/ doxia-all
# https://builds.apache.org/job/doxia-eclipse-editor/ doxia-eclipse-editor
# https://builds.apache.org/job/doxia-sitetools/ doxia-sitetools
# https://builds.apache.org/job/doxia-tools/ doxia-tools
# https://builds.apache.org/job/Drill%20-%20Prototype%20-%20build/ Drill - Prototype - build
# https://builds.apache.org/job/Drill-Physical-Plan/ Drill-Physical-Plan
# https://builds.apache.org/job/drill-scm/ drill-scm
# https://builds.apache.org/job/EasyAnt/ EasyAnt
# https://builds.apache.org/job/Empire-db%20multios/ Empire-db multios
# https://builds.apache.org/job/Empire-db%20reports/ Empire-db reports
# https://builds.apache.org/job/Empire-db%20snapshot/ Empire-db snapshot
# https://builds.apache.org/job/Environment%20check/ Environment check
# https://builds.apache.org/job/ESME/ ESME
# https://builds.apache.org/job/etch-trunk-linux-x86/ etch-trunk-linux-x86
# https://builds.apache.org/job/etch-trunk-linux-x86-experimental/ etch-trunk-linux-x86-experimental
# https://builds.apache.org/job/etch-trunk-windows-x86/ etch-trunk-windows-x86
# https://builds.apache.org/job/etch-trunk-windows-x86-experimental/ etch-trunk-windows-x86-experimental
# https://builds.apache.org/job/ExtVal%20for%20JSF%201.2%20(deploy)/ ExtVal for JSF 1.2 (deploy)
# https://builds.apache.org/job/ExtVal%20for%20JSF%201.2%20(nightly)/ ExtVal for JSF 1.2 (nightly)
# https://builds.apache.org/job/ExtVal%20for%20JSF%202.0%20(deploy)/ ExtVal for JSF 2.0 (deploy)
# https://builds.apache.org/job/ExtVal%20for%20JSF%202.0%20(nightly)/ ExtVal for JSF 2.0 (nightly)
# https://builds.apache.org/job/Felix%20iPOJO%20API/ Felix iPOJO API
# https://builds.apache.org/job/Felix%20iPOJO%20Arch/ Felix iPOJO Arch
# https://builds.apache.org/job/Felix%20iPOJO%20Arch-Gogo/ Felix iPOJO Arch-Gogo
# https://builds.apache.org/job/Felix%20iPOJO%20EventAdmin%20Handler/ Felix iPOJO EventAdmin Handler
# https://builds.apache.org/job/Felix%20iPOJO%20Extender%20Handler/ Felix iPOJO Extender Handler
# https://builds.apache.org/job/Felix%20iPOJO%20JMX%20Handler/ Felix iPOJO JMX Handler
# https://builds.apache.org/job/Felix%20iPOJO%20Junit4OSGi/ Felix iPOJO Junit4OSGi
# https://builds.apache.org/job/Felix%20iPOJO%20Manipulator/ Felix iPOJO Manipulator
# https://builds.apache.org/job/Felix%20iPOJO%20Metadata/ Felix iPOJO Metadata
# https://builds.apache.org/job/Felix%20iPOJO%20Runtime/ Felix iPOJO Runtime
# https://builds.apache.org/job/Felix%20iPOJO%20Temporal%20Handler/ Felix iPOJO Temporal Handler
# https://builds.apache.org/job/Felix%20iPOJO%20Tests/ Felix iPOJO Tests
# https://builds.apache.org/job/Felix%20iPOJO%20Transaction%20Handler/ Felix iPOJO Transaction Handler
# https://builds.apache.org/job/Felix%20iPOJO%20Webconsole/ Felix iPOJO Webconsole
# https://builds.apache.org/job/Felix%20iPOJO%20Whiteboard%20Handler/ Felix iPOJO Whiteboard Handler
# https://builds.apache.org/job/Felix-FileInstall/ Felix-FileInstall
# https://builds.apache.org/job/Felix-Gogo/ Felix-Gogo
# https://builds.apache.org/job/Felix-WebConsole/ Felix-WebConsole
# https://builds.apache.org/job/flex-asjs/ flex-asjs
# https://builds.apache.org/job/flex-asjs%20(maven)/ flex-asjs (maven)
# https://builds.apache.org/job/flex-blazeds/ flex-blazeds
# https://builds.apache.org/job/flex-falcon/ flex-falcon
# https://builds.apache.org/job/flex-falcon%20(maven)/ flex-falcon (maven)
# https://builds.apache.org/job/flex-flexunit/ flex-flexunit
# https://builds.apache.org/job/flex-pmd/ flex-pmd
# https://builds.apache.org/job/flex-productdashboard/ flex-productdashboard
# https://builds.apache.org/job/flex-sdk/ flex-sdk
# https://builds.apache.org/job/flex-sdk-converter/ flex-sdk-converter
# https://builds.apache.org/job/flex-sdk_pixelbender/ flex-sdk_pixelbender
# https://builds.apache.org/job/flex-sdk_release/ flex-sdk_release
# https://builds.apache.org/job/flex-tlf/ flex-tlf
# https://builds.apache.org/job/flex-tool-api/ flex-tool-api
# https://builds.apache.org/job/flink-ci/ flink-ci
# https://builds.apache.org/job/flink-snapshot-deployment/ flink-snapshot-deployment
# https://builds.apache.org/job/flume-0.9/ flume-0.9
# https://builds.apache.org/job/flume-1.3.0/ flume-1.3.0
# https://builds.apache.org/job/flume-1.4.0/ flume-1.4.0
# https://builds.apache.org/job/Flume-1.6-HBase-98/ Flume-1.6-HBase-98
# https://builds.apache.org/job/flume-trunk/ flume-trunk
# https://builds.apache.org/job/Flume-trunk-hbase-1/ Flume-trunk-hbase-1
# https://builds.apache.org/job/FontBox-trunk/ FontBox-trunk
# https://builds.apache.org/job/ftpserver-1.0.x-jdk1.5-solaris/ ftpserver-1.0.x-jdk1.5-solaris
# https://builds.apache.org/job/ftpserver-1.0.x-jdk1.5-ubuntu/ ftpserver-1.0.x-jdk1.5-ubuntu
# https://builds.apache.org/job/ftpserver-trunk-jdk1.5-ibm-ubuntu/ ftpserver-trunk-jdk1.5-ibm-ubuntu
# https://builds.apache.org/job/ftpserver-trunk-jdk1.5-solaris/ ftpserver-trunk-jdk1.5-solaris
# https://builds.apache.org/job/ftpserver-trunk-jdk1.5-ubuntu/ ftpserver-trunk-jdk1.5-ubuntu
# https://builds.apache.org/job/ftpserver-trunk-jdk1.6-freebsd/ ftpserver-trunk-jdk1.6-freebsd
# https://builds.apache.org/job/ftpserver-trunk-jdk1.6-ibm-ubuntu/ ftpserver-trunk-jdk1.6-ibm-ubuntu
# https://builds.apache.org/job/ftpserver-trunk-jdk1.6-osx/ ftpserver-trunk-jdk1.6-osx
# https://builds.apache.org/job/ftpserver-trunk-jdk1.6-solaris/ ftpserver-trunk-jdk1.6-solaris
# https://builds.apache.org/job/ftpserver-trunk-jdk1.6-ubuntu/ ftpserver-trunk-jdk1.6-ubuntu
# https://builds.apache.org/job/ftpserver-trunk-jdk1.6-windows/ ftpserver-trunk-jdk1.6-windows
# https://builds.apache.org/job/gcc-test-vinod/ gcc-test-vinod
# https://builds.apache.org/job/Geode-nightly/ Geode-nightly
# https://builds.apache.org/job/Geode-nightly-copy/ Geode-nightly-copy
# https://builds.apache.org/job/Geode-release/ Geode-release
# https://builds.apache.org/job/Geode-spark-connector/ Geode-spark-connector
# https://builds.apache.org/job/Geode-trunk-test-patch/ Geode-trunk-test-patch
# https://builds.apache.org/job/Geronimo%20Spec%20JMS%202.0/ Geronimo Spec JMS 2.0
# https://builds.apache.org/job/Geronimo-Specs-trunk/ Geronimo-Specs-trunk
# https://builds.apache.org/job/Giraph-1.1/ Giraph-1.1
# https://builds.apache.org/job/Giraph-1.1.0-old/ Giraph-1.1.0-old
# https://builds.apache.org/job/Giraph-trunk-Commit/ Giraph-trunk-Commit
# https://builds.apache.org/job/Giraph-trunk-default-deploy/ Giraph-trunk-default-deploy
# https://builds.apache.org/job/giraph-trunk-hadoop-0.20.203/ giraph-trunk-hadoop-0.20.203
# https://builds.apache.org/job/giraph-trunk-hadoop-0.23/ giraph-trunk-hadoop-0.23
# https://builds.apache.org/job/giraph-trunk-hadoop-1.0/ giraph-trunk-hadoop-1.0
# https://builds.apache.org/job/giraph-trunk-hadoop-trunk/ giraph-trunk-hadoop-trunk
# https://builds.apache.org/job/Giraph-trunk-hadoop2-deploy/ Giraph-trunk-hadoop2-deploy
# https://builds.apache.org/job/giraph-trunk-non-secure/ giraph-trunk-non-secure
# https://builds.apache.org/job/Giraph-trunk-site/ Giraph-trunk-site
# https://builds.apache.org/job/gora-trunk/ gora-trunk
# https://builds.apache.org/job/Groovy%20Github%20PRs/ Groovy Github PRs
# https://builds.apache.org/job/Groovy%20Pull%20Requests%20Matrix%20Job/ Groovy Pull Requests Matrix Job
# https://builds.apache.org/job/Groovy%20Ubuntu/ Groovy Ubuntu
# https://builds.apache.org/job/Groovy%20Windows/ Groovy Windows
# https://builds.apache.org/job/Hadoop-ATS-v2/ Hadoop-ATS-v2
# https://builds.apache.org/job/Hadoop-branch2/ Hadoop-branch2
# https://builds.apache.org/job/Hadoop-branch2-parameterized/ Hadoop-branch2-parameterized
# https://builds.apache.org/job/Hadoop-Common-2-Build/ Hadoop-Common-2-Build
# https://builds.apache.org/job/Hadoop-Common-2-Commit/ Hadoop-Common-2-Commit
# https://builds.apache.org/job/Hadoop-Common-trunk/ Hadoop-Common-trunk
# https://builds.apache.org/job/Hadoop-common-trunk-Java8/ Hadoop-common-trunk-Java8
# https://builds.apache.org/job/Hadoop-Common-trunk-win/ Hadoop-Common-trunk-win
# https://builds.apache.org/job/Hadoop-fs-encryption-nightly/ Hadoop-fs-encryption-nightly
# https://builds.apache.org/job/Hadoop-Hdfs-7966/ Hadoop-Hdfs-7966
# https://builds.apache.org/job/Hadoop-HDFS-8833/ Hadoop-HDFS-8833
# https://builds.apache.org/job/Hadoop-HDFS-8909/ Hadoop-HDFS-8909
# https://builds.apache.org/job/Hadoop-Hdfs-HAbranch-build/ Hadoop-Hdfs-HAbranch-build
# https://builds.apache.org/job/Hadoop-Hdfs-NIFbranch-build/ Hadoop-Hdfs-NIFbranch-build
# https://builds.apache.org/job/Hadoop-Hdfs-trunk/ Hadoop-Hdfs-trunk
# https://builds.apache.org/job/Hadoop-Hdfs-trunk-Commit/ Hadoop-Hdfs-trunk-Commit
# https://builds.apache.org/job/Hadoop-Hdfs-trunk-Java8/ Hadoop-Hdfs-trunk-Java8
# https://builds.apache.org/job/Hadoop-Hdfs-trunk-win/ Hadoop-Hdfs-trunk-win
# https://builds.apache.org/job/Hadoop-integration-tests/ Hadoop-integration-tests
# https://builds.apache.org/job/Hadoop-Mapreduce-trunk/ Hadoop-Mapreduce-trunk
# https://builds.apache.org/job/Hadoop-Mapreduce-trunk-Commit/ Hadoop-Mapreduce-trunk-Commit
# https://builds.apache.org/job/Hadoop-Mapreduce-trunk-Java8/ Hadoop-Mapreduce-trunk-Java8
# https://builds.apache.org/job/Hadoop-Mapreduce-trunk-win/ Hadoop-Mapreduce-trunk-win
# https://builds.apache.org/job/hadoop-qbt/ hadoop-qbt
# https://builds.apache.org/job/hadoop-qbt-test/ hadoop-qbt-test
# https://builds.apache.org/job/Hadoop-trunk/ Hadoop-trunk
# https://builds.apache.org/job/Hadoop-trunk-ARM/ Hadoop-trunk-ARM
# https://builds.apache.org/job/Hadoop-trunk-Commit/ Hadoop-trunk-Commit
# https://builds.apache.org/job/hadoop-trunk-osx-java8/ hadoop-trunk-osx-java8
# https://builds.apache.org/job/hadoop-trunk-solaris-java8/ hadoop-trunk-solaris-java8
# https://builds.apache.org/job/hadoop-trunk-win-java8/ hadoop-trunk-win-java8
# https://builds.apache.org/job/hadoop-win1/ hadoop-win1
# https://builds.apache.org/job/Hadoop-Yarn-trunk/ Hadoop-Yarn-trunk
# https://builds.apache.org/job/Hadoop-Yarn-trunk-Java8/ Hadoop-Yarn-trunk-Java8
# https://builds.apache.org/job/HADOOP2_Release_Artifacts_Builder/ HADOOP2_Release_Artifacts_Builder
# https://builds.apache.org/job/Hama-Nightly-for-Hadoop-1.x/ Hama-Nightly-for-Hadoop-1.x
# https://builds.apache.org/job/Hama-Nightly-for-Hadoop-2.x/ Hama-Nightly-for-Hadoop-2.x
# https://builds.apache.org/job/Hama-trunk/ Hama-trunk
# https://builds.apache.org/job/HAWQ%20Downloads/ HAWQ Downloads
# https://builds.apache.org/job/HAWQ%20SCM%20Build/ HAWQ SCM Build
# https://builds.apache.org/job/HAWQ-build-pullrequest/ HAWQ-build-pullrequest
# https://builds.apache.org/job/HAWQ-libhdfs-nightly/ HAWQ-libhdfs-nightly
# https://builds.apache.org/job/HAWQ-libyarn-nightly/ HAWQ-libyarn-nightly
# https://builds.apache.org/job/HAWQ-nightly/ HAWQ-nightly
# https://builds.apache.org/job/HBase%20Website%20Link%20Ckecker/ HBase Website Link Ckecker
# https://builds.apache.org/job/HBase-0.94/ HBase-0.94
# https://builds.apache.org/job/HBase-0.94-JDK7/ HBase-0.94-JDK7
# https://builds.apache.org/job/HBase-0.94-on-Hadoop-2/ HBase-0.94-on-Hadoop-2
# https://builds.apache.org/job/HBase-0.94-security/ HBase-0.94-security
# https://builds.apache.org/job/HBase-0.94.18-security/ HBase-0.94.18-security
# https://builds.apache.org/job/HBase-0.94.28/ HBase-0.94.28
# https://builds.apache.org/job/HBase-0.98/ HBase-0.98
# https://builds.apache.org/job/HBase-0.98-matrix/ HBase-0.98-matrix
# https://builds.apache.org/job/HBase-0.98-on-Hadoop-1.1/ HBase-0.98-on-Hadoop-1.1
# https://builds.apache.org/job/HBase-1.0/ HBase-1.0
# https://builds.apache.org/job/HBase-1.1/ HBase-1.1
# https://builds.apache.org/job/HBase-1.1-JDK7/ HBase-1.1-JDK7
# https://builds.apache.org/job/HBase-1.1-JDK8/ HBase-1.1-JDK8
# https://builds.apache.org/job/HBase-1.2/ HBase-1.2
# https://builds.apache.org/job/HBase-1.2%20non-matrix/ HBase-1.2 non-matrix
# https://builds.apache.org/job/HBase-1.2-IT/ HBase-1.2-IT
# https://builds.apache.org/job/HBase-1.3/ HBase-1.3
# https://builds.apache.org/job/HBase-1.3-IT/ HBase-1.3-IT
# https://builds.apache.org/job/HBase-1.4/ HBase-1.4
# https://builds.apache.org/job/HBase-Find-Flaky-Tests/ HBase-Find-Flaky-Tests
# https://builds.apache.org/job/HBase-Flaky-Tests/ HBase-Flaky-Tests
# https://builds.apache.org/job/hbase-qbt-test/ hbase-qbt-test
# https://builds.apache.org/job/HBase-TRUNK/ HBase-TRUNK
# https://builds.apache.org/job/HBase-Trunk-IT/ HBase-Trunk-IT
# https://builds.apache.org/job/HBase-Trunk_matrix/ HBase-Trunk_matrix
# https://builds.apache.org/job/hbase_generate_website/ hbase_generate_website
# https://builds.apache.org/job/HDT-hadoop-eclipse-merge/ HDT-hadoop-eclipse-merge
# https://builds.apache.org/job/helix/ helix
# https://builds.apache.org/job/helix-1.7/ helix-1.7
# https://builds.apache.org/job/Hive-0.14/ Hive-0.14
# https://builds.apache.org/job/Hive-trunk/ Hive-trunk
# https://builds.apache.org/job/HTrace-Master/ HTrace-Master
# https://builds.apache.org/job/httpcomponents-asyncclient-4.1.x/ httpcomponents-asyncclient-4.1.x
# https://builds.apache.org/job/httpcomponents-asyncclient-trunk/ httpcomponents-asyncclient-trunk
# https://builds.apache.org/job/httpcomponents-client-4.5.x/ httpcomponents-client-4.5.x
# https://builds.apache.org/job/httpcomponents-client-5.x/ httpcomponents-client-5.x
# https://builds.apache.org/job/httpcomponents-core-4.4.x/ httpcomponents-core-4.4.x
# https://builds.apache.org/job/httpcomponents-core-5.x/ httpcomponents-core-5.x
# https://builds.apache.org/job/hupa-trunk/ hupa-trunk
# https://builds.apache.org/job/hupa-trunk-site/ hupa-trunk-site
# https://builds.apache.org/job/Ignite-artifacts/ Ignite-artifacts
# https://builds.apache.org/job/Ignite-nightly/ Ignite-nightly
# https://builds.apache.org/job/imap-trunk-m2/ imap-trunk-m2
# https://builds.apache.org/job/imap-trunk-site/ imap-trunk-site
# https://builds.apache.org/job/incubator-brooklyn-master-build/ incubator-brooklyn-master-build
# https://builds.apache.org/job/incubator-brooklyn-master-integration/ incubator-brooklyn-master-integration
# https://builds.apache.org/job/incubator-brooklyn-master-windows/ incubator-brooklyn-master-windows
# https://builds.apache.org/job/incubator-brooklyn-pull-requests/ incubator-brooklyn-pull-requests
# https://builds.apache.org/job/incubator-commonsrdf/ incubator-commonsrdf
# https://builds.apache.org/job/incubator-eagle-main/ incubator-eagle-main
# https://builds.apache.org/job/incubator-eagle-pr-reviewer/ incubator-eagle-pr-reviewer
# https://builds.apache.org/job/incubator-eagle-test/ incubator-eagle-test
# https://builds.apache.org/job/incubator-rya-develop/ incubator-rya-develop
# https://builds.apache.org/job/incubator-taverna-commandline/ incubator-taverna-commandline
# https://builds.apache.org/job/incubator-taverna-commandline-nightly/ incubator-taverna-commandline-nightly
# https://builds.apache.org/job/incubator-taverna-common-activities/ incubator-taverna-common-activities
# https://builds.apache.org/job/incubator-taverna-engine/ incubator-taverna-engine
# https://builds.apache.org/job/incubator-taverna-language/ incubator-taverna-language
# https://builds.apache.org/job/incubator-taverna-language-pull-requests/ incubator-taverna-language-pull-requests
# https://builds.apache.org/job/incubator-taverna-maven-parent/ incubator-taverna-maven-parent
# https://builds.apache.org/job/incubator-taverna-osgi/ incubator-taverna-osgi
# https://builds.apache.org/job/incubator-taverna-plugin-bioinformatics/ incubator-taverna-plugin-bioinformatics
# https://builds.apache.org/job/incubator-taverna-plugin-component/ incubator-taverna-plugin-component
# https://builds.apache.org/job/incubator-taverna-server/ incubator-taverna-server
# https://builds.apache.org/job/incubator-taverna-workbench/ incubator-taverna-workbench
# https://builds.apache.org/job/incubator-taverna-workbench-common-activities/ incubator-taverna-workbench-common-activities
# https://builds.apache.org/job/incubator-taverna-workbench-product/ incubator-taverna-workbench-product
# https://builds.apache.org/job/isis-core-ubuntu/ isis-core-ubuntu
# https://builds.apache.org/job/Ivy/ Ivy
# https://builds.apache.org/job/Ivy-check/ Ivy-check
# https://builds.apache.org/job/Ivy-tests/ Ivy-tests
# https://builds.apache.org/job/IvyDE/ IvyDE
# https://builds.apache.org/job/IvyDE-updatesite/ IvyDE-updatesite
# https://builds.apache.org/job/Jackrabbit%20Oak%20trunk%20with%20JR%20SNAPSHOT/ Jackrabbit Oak trunk with JR SNAPSHOT
# https://builds.apache.org/job/Jackrabbit-2.2/ Jackrabbit-2.2
# https://builds.apache.org/job/Jackrabbit-trunk/ Jackrabbit-trunk
# https://builds.apache.org/job/Jakarta_BSF3/ Jakarta_BSF3
# https://builds.apache.org/job/james-mailet/ james-mailet
# https://builds.apache.org/job/james-project/ james-project
# https://builds.apache.org/job/james-server-trunk/ james-server-trunk
# ...
# https://builds.apache.org/job/sling-ide/ sling-ide
# https://builds.apache.org/job/sling-oak-it-1.7/ sling-oak-it-1.7
# https://builds.apache.org/job/sling-samples-1.7/ sling-samples-1.7
# https://builds.apache.org/job/sling-tooling-trunk-1.7/ sling-tooling-trunk-1.7
# https://builds.apache.org/job/sling-trunk-1.7/ sling-trunk-1.7
# https://builds.apache.org/job/sling-trunk-1.8/ sling-trunk-1.8
# https://builds.apache.org/job/sling-trunk-gitbranch-1.7/ sling-trunk-gitbranch-1.7
# https://builds.apache.org/job/Solaris1/ Solaris1
# https://builds.apache.org/job/Solaris2/ Solaris2
# https://builds.apache.org/job/Solr-Artifacts-5.5/ Solr-Artifacts-5.5
# https://builds.apache.org/job/Solr-Artifacts-6.0/ Solr-Artifacts-6.0
# https://builds.apache.org/job/Solr-Artifacts-6.x/ Solr-Artifacts-6.x
# https://builds.apache.org/job/Solr-Artifacts-master/ Solr-Artifacts-master
# https://builds.apache.org/job/SpamAssassin-trunk/ SpamAssassin-trunk
# https://builds.apache.org/job/SpamAssassin-trunk-FreeBSD/ SpamAssassin-trunk-FreeBSD
# https://builds.apache.org/job/Sqoop-hadoop100/ Sqoop-hadoop100
# https://builds.apache.org/job/Sqoop-hadoop20/ Sqoop-hadoop20
# https://builds.apache.org/job/Sqoop-hadoop200/ Sqoop-hadoop200
# https://builds.apache.org/job/Sqoop-hadoop23/ Sqoop-hadoop23
# https://builds.apache.org/job/Sqoop2/ Sqoop2
# https://builds.apache.org/job/Sqoop2-cobertura/ Sqoop2-cobertura
# https://builds.apache.org/job/stanbol-0.12/ stanbol-0.12
# https://builds.apache.org/job/stanbol-trunk/ stanbol-trunk
# https://builds.apache.org/job/stanbol-trunk-openjdk-8/ stanbol-trunk-openjdk-8
# https://builds.apache.org/job/stdcxx-4.2.2-12d-ubuntu/ stdcxx-4.2.2-12d-ubuntu
# https://builds.apache.org/job/stdcxx-4.2.2-12S-freebsd/ stdcxx-4.2.2-12S-freebsd
# https://builds.apache.org/job/stdcxx-4.2.2-15D-windows/ stdcxx-4.2.2-15D-windows
# https://builds.apache.org/job/stdcxx-4.2.2-15s-solaris/ stdcxx-4.2.2-15s-solaris
# https://builds.apache.org/job/Storm/ Storm
# https://builds.apache.org/job/storm-master-build/ storm-master-build
# https://builds.apache.org/job/Stratos-41x-Commit-Build/ Stratos-41x-Commit-Build
# https://builds.apache.org/job/Stratos-41x-Nightly-Build/ Stratos-41x-Nightly-Build
# https://builds.apache.org/job/Stratos-Master-Commit-Build/ Stratos-Master-Commit-Build
# https://builds.apache.org/job/Stratos-Master-Nightly-Build/ Stratos-Master-Nightly-Build
# https://builds.apache.org/job/Streams%20Examples/ Streams Examples
# https://builds.apache.org/job/Streams%20Master/ Streams Master
# https://builds.apache.org/job/Streams%20Project%20Site/ Streams Project Site
# https://builds.apache.org/job/Streams%20Trunk/ Streams Trunk
# https://builds.apache.org/job/struts-annotations/ struts-annotations
# https://builds.apache.org/job/Struts-examples-JDK8-master/ Struts-examples-JDK8-master
# https://builds.apache.org/job/Struts-JDK6-support-2.3/ Struts-JDK6-support-2.3
# https://builds.apache.org/job/Struts-JDK7-master/ Struts-JDK7-master
# https://builds.apache.org/job/Struts-JDK7-pull-request/ Struts-JDK7-pull-request
# https://builds.apache.org/job/Struts-JDK8-master/ Struts-JDK8-master
# https://builds.apache.org/job/Struts-JDK9-master/ Struts-JDK9-master
# https://builds.apache.org/job/struts-master/ struts-master
# https://builds.apache.org/job/subversion-1.6.x-solaris/ subversion-1.6.x-solaris
# https://builds.apache.org/job/subversion-1.6.x-ubuntu/ subversion-1.6.x-ubuntu
# https://builds.apache.org/job/subversion-doxygen/ subversion-doxygen
# https://builds.apache.org/job/subversion-javadoc/ subversion-javadoc
# https://builds.apache.org/job/subversion-trunk-solaris/ subversion-trunk-solaris
# https://builds.apache.org/job/subversion-trunk-ubuntu/ subversion-trunk-ubuntu
# https://builds.apache.org/job/subversion-trunk-windows/ subversion-trunk-windows
# https://builds.apache.org/job/Synapse%20-%20Trunk/ Synapse - Trunk
# https://builds.apache.org/job/Syncope-1_0_X/ Syncope-1_0_X
# https://builds.apache.org/job/Syncope-1_1_X/ Syncope-1_1_X
# https://builds.apache.org/job/Syncope-1_2_X/ Syncope-1_2_X
# https://builds.apache.org/job/Syncope-master/ Syncope-master
# https://builds.apache.org/job/Syncope-trunk%20(Windows)/ Syncope-trunk (Windows)
# https://builds.apache.org/job/taglib-extended/ taglib-extended
# https://builds.apache.org/job/taglib-parent/ taglib-parent
# https://builds.apache.org/job/taglib-rdc/ taglib-rdc
# https://builds.apache.org/job/taglib-standard/ taglib-standard
# https://builds.apache.org/job/Tajo-0.11.4-build/ Tajo-0.11.4-build
# https://builds.apache.org/job/Tajo-0.11.4-nightly/ Tajo-0.11.4-nightly
# https://builds.apache.org/job/Tajo-block_iteration-branch-build/ Tajo-block_iteration-branch-build
# https://builds.apache.org/job/Tajo-master-build/ Tajo-master-build
# https://builds.apache.org/job/Tajo-master-CODEGEN-build/ Tajo-master-CODEGEN-build
# https://builds.apache.org/job/Tajo-master-nightly/ Tajo-master-nightly
# https://builds.apache.org/job/Tamaya-Javadoc-Master/ Tamaya-Javadoc-Master
# https://builds.apache.org/job/Tamaya-Master-branch/ Tamaya-Master-branch
# https://builds.apache.org/job/Tamaya-Site-Master/ Tamaya-Site-Master
# https://builds.apache.org/job/tapestry-4.1-trunk/ tapestry-4.1-trunk
# https://builds.apache.org/job/tapestry-5.1-freestyle/ tapestry-5.1-freestyle
# https://builds.apache.org/job/tapestry-trunk-freestyle/ tapestry-trunk-freestyle
# https://builds.apache.org/job/Test/ Test
# https://builds.apache.org/job/Test%20build/ Test build
# https://builds.apache.org/job/test-cpus/ test-cpus
# https://builds.apache.org/job/test-ulimit/ test-ulimit
# https://builds.apache.org/job/TestBuilds/ TestBuilds
# https://builds.apache.org/job/Tez-0.5/ Tez-0.5
# https://builds.apache.org/job/Tez-Build/ Tez-Build
# https://builds.apache.org/job/Tez-Build-branch-0.6/ Tez-Build-branch-0.6
# https://builds.apache.org/job/Tez-Build-branch-0.7/ Tez-Build-branch-0.7
# https://builds.apache.org/job/Tez-Build-branch-0.8/ Tez-Build-branch-0.8
# https://builds.apache.org/job/Tez-Build-branch-tez-2003/ Tez-Build-branch-tez-2003
# https://builds.apache.org/job/Tez-Build-branch-TEZ-2980/ Tez-Build-branch-TEZ-2980
# https://builds.apache.org/job/Tez-Build-Hadoop-2.2/ Tez-Build-Hadoop-2.2
# https://builds.apache.org/job/Tez-Build-Hadoop-2.4/ Tez-Build-Hadoop-2.4
# https://builds.apache.org/job/Tez-Build-Java8/ Tez-Build-Java8
# https://builds.apache.org/job/Thrift/ Thrift
# https://builds.apache.org/job/Thrift-precommit/ Thrift-precommit
# https://builds.apache.org/job/tika-2.x/ tika-2.x
# https://builds.apache.org/job/tika-2.x-windows/ tika-2.x-windows
# https://builds.apache.org/job/Tika-trunk/ Tika-trunk
# https://builds.apache.org/job/tika-trunk-jdk1.6/ tika-trunk-jdk1.6
# https://builds.apache.org/job/tika-trunk-jdk1.7/ tika-trunk-jdk1.7
# https://builds.apache.org/job/tika-trunk-jdk1.8/ tika-trunk-jdk1.8
# https://builds.apache.org/job/Tiles-AutoTag/ Tiles-AutoTag
# https://builds.apache.org/job/Tiles-AutoTag-Java6/ Tiles-AutoTag-Java6
# https://builds.apache.org/job/Tiles-Framework/ Tiles-Framework
# https://builds.apache.org/job/Tiles-Framework-3.0.x/ Tiles-Framework-3.0.x
# https://builds.apache.org/job/Tiles-Framework-3.0.x-Java6/ Tiles-Framework-3.0.x-Java6
# https://builds.apache.org/job/Tiles-Framework-Java6/ Tiles-Framework-Java6
# https://builds.apache.org/job/Tiles-Request/ Tiles-Request
# https://builds.apache.org/job/Tiles-Request-1.0.x/ Tiles-Request-1.0.x
# https://builds.apache.org/job/Tiles-Request-1.0.x-Java6/ Tiles-Request-1.0.x-Java6
# https://builds.apache.org/job/Tiles-Request-Java6/ Tiles-Request-Java6
# https://builds.apache.org/job/tinkerpop-master/ tinkerpop-master
# https://builds.apache.org/job/Tobago%201.0.x/ Tobago 1.0.x
# https://builds.apache.org/job/Tobago%201.0.x%20(deploy)/ Tobago 1.0.x (deploy)
# https://builds.apache.org/job/Tobago%201.5.x/ Tobago 1.5.x
# https://builds.apache.org/job/Tobago%201.5.x%20(deploy)/ Tobago 1.5.x (deploy)
# https://builds.apache.org/job/Tobago%202.0.x/ Tobago 2.0.x
# https://builds.apache.org/job/Tobago%202.0.x%20(deploy)/ Tobago 2.0.x (deploy)
# https://builds.apache.org/job/Tobago%203.0.x/ Tobago 3.0.x
# https://builds.apache.org/job/Tobago%203.0.x%20(deploy)/ Tobago 3.0.x (deploy)
# https://builds.apache.org/job/Tobago%203.0.x%20integration-test/ Tobago 3.0.x integration-test
# https://builds.apache.org/job/Tomcat-7.x/ Tomcat-7.x
# https://builds.apache.org/job/Tomcat-7.x-Maven/ Tomcat-7.x-Maven
# https://builds.apache.org/job/TomcatMavenPlugin-mvn2.x/ TomcatMavenPlugin-mvn2.x
# https://builds.apache.org/job/TomcatMavenPlugin-mvn3.x/ TomcatMavenPlugin-mvn3.x
# https://builds.apache.org/job/TomcatMavenPlugin-mvn3.x-windows/ TomcatMavenPlugin-mvn3.x-windows
# https://builds.apache.org/job/torque4-test-project-derby/ torque4-test-project-derby
# https://builds.apache.org/job/torque4-test-project-hsqldb/ torque4-test-project-hsqldb
# https://builds.apache.org/job/Torque4-trunk/ Torque4-trunk
# https://builds.apache.org/job/traffic-trunk/ traffic-trunk
# https://builds.apache.org/job/Trinidad%20Core%201.0.x%20(sanity)/ Trinidad Core 1.0.x (sanity)
# https://builds.apache.org/job/Trinidad%20Core%201.2.x%20(sanity)/ Trinidad Core 1.2.x (sanity)
# https://builds.apache.org/job/Trinidad%20Core%202.0.x%20(sanity)/ Trinidad Core 2.0.x (sanity)
# https://builds.apache.org/job/Trinidad%20Core%202.0.x%20(snapshot)/ Trinidad Core 2.0.x (snapshot)
# https://builds.apache.org/job/Trinidad%20Core%20Trunk%20(sanity)/ Trinidad Core Trunk (sanity)
# https://builds.apache.org/job/Trinidad%20Core%20Trunk%20(snapshot)/ Trinidad Core Trunk (snapshot)
# https://builds.apache.org/job/Trinidad%20Plugins%201.2.x%20(snapshot)/ Trinidad Plugins 1.2.x (snapshot)
# https://builds.apache.org/job/Trinidad%20Plugins%202.0.x%20(snapshot)/ Trinidad Plugins 2.0.x (snapshot)
# https://builds.apache.org/job/Trinidad%20Site/ Trinidad Site
# https://builds.apache.org/job/Turbine%20Core/ Turbine Core
# https://builds.apache.org/job/Turbine%20Fulcrum/ Turbine Fulcrum
# https://builds.apache.org/job/Tuscany-1x/ Tuscany-1x
# https://builds.apache.org/job/Tuscany-2x/ Tuscany-2x
# https://builds.apache.org/job/Tuscany-2x-all/ Tuscany-2x-all
# https://builds.apache.org/job/Tuscany-2x-compliance/ Tuscany-2x-compliance
# https://builds.apache.org/job/Tuscany-2x-deploy/ Tuscany-2x-deploy
# https://builds.apache.org/job/Tuscany-2x-distributions/ Tuscany-2x-distributions
# https://builds.apache.org/job/Tuscany-DAS/ Tuscany-DAS
# https://builds.apache.org/job/Tuscany-quick-all-distro/ Tuscany-quick-all-distro
# https://builds.apache.org/job/Tuscany-SDO/ Tuscany-SDO
# https://builds.apache.org/job/UIMA%20Addons/ UIMA Addons
# https://builds.apache.org/job/UIMA-AS/ UIMA-AS
# https://builds.apache.org/job/UIMA-DUCC/ UIMA-DUCC
# https://builds.apache.org/job/UIMA-Ruta/ UIMA-Ruta
# https://builds.apache.org/job/UIMA-SDK/ UIMA-SDK
# https://builds.apache.org/job/UIMA-uima-parent-pom/ UIMA-uima-parent-pom
# https://builds.apache.org/job/UIMA-uimaFIT/ UIMA-uimaFIT
# https://builds.apache.org/job/UIMA-uimaFIT_2_1_x/ UIMA-uimaFIT_2_1_x
# https://builds.apache.org/job/UIMA-uimaFIT_java8/ UIMA-uimaFIT_java8
# https://builds.apache.org/job/UIMAJ-SDK_java8/ UIMAJ-SDK_java8
# https://builds.apache.org/job/unomi-master/ unomi-master
# https://builds.apache.org/job/Usergrid-master/ Usergrid-master
# https://builds.apache.org/job/usergrid-portal-master/ usergrid-portal-master
# https://builds.apache.org/job/usergrid-stack/ usergrid-stack
# https://builds.apache.org/job/vinod-docker/ vinod-docker
# https://builds.apache.org/job/vinod-docker-params/ vinod-docker-params
# https://builds.apache.org/job/vinod-test/ vinod-test
# https://builds.apache.org/job/vysper-trunk-harmony1.5-ubuntu/ vysper-trunk-harmony1.5-ubuntu
# https://builds.apache.org/job/vysper-trunk-jdk1.5-ibm-ubuntu/ vysper-trunk-jdk1.5-ibm-ubuntu
# https://builds.apache.org/job/vysper-trunk-jdk1.5-solaris/ vysper-trunk-jdk1.5-solaris
# https://builds.apache.org/job/vysper-trunk-jdk1.5-ubuntu/ vysper-trunk-jdk1.5-ubuntu
# https://builds.apache.org/job/vysper-trunk-jdk1.6-ibm-ubuntu/ vysper-trunk-jdk1.6-ibm-ubuntu
# https://builds.apache.org/job/vysper-trunk-jdk1.6-solaris/ vysper-trunk-jdk1.6-solaris
# https://builds.apache.org/job/vysper-trunk-jdk1.6-ubuntu/ vysper-trunk-jdk1.6-ubuntu
# https://builds.apache.org/job/vysper-trunk-jdk1.6-windows/ vysper-trunk-jdk1.6-windows
# https://builds.apache.org/job/wave-all_tests/ wave-all_tests
# https://builds.apache.org/job/wave-artifacts/ wave-artifacts
# https://builds.apache.org/job/wave-small_tests/ wave-small_tests
# https://builds.apache.org/job/Whirr-Solaris/ Whirr-Solaris
# https://builds.apache.org/job/Whirr-Ubuntu/ Whirr-Ubuntu
# https://builds.apache.org/job/Windows1/ Windows1
# https://builds.apache.org/job/Wink-Trunk-JDK1.5/ Wink-Trunk-JDK1.5
# https://builds.apache.org/job/Wink-Trunk-JDK1.5-itests/ Wink-Trunk-JDK1.5-itests
# https://builds.apache.org/job/Wink-Trunk-JDK1.6/ Wink-Trunk-JDK1.6
# https://builds.apache.org/job/Wink-Trunk-JDK1.6-itests/ Wink-Trunk-JDK1.6-itests
# https://builds.apache.org/job/Wink-Trunk-JDK1.7/ Wink-Trunk-JDK1.7
# https://builds.apache.org/job/Wink2-Trunk-JDK1.6/ Wink2-Trunk-JDK1.6
# https://builds.apache.org/job/woden-trunk/ woden-trunk
# https://builds.apache.org/job/ws-parent/ ws-parent
# https://builds.apache.org/job/wss4j-2.0/ wss4j-2.0
# https://builds.apache.org/job/wss4j-2.1/ wss4j-2.1
# https://builds.apache.org/job/wss4j-trunk/ wss4j-trunk
# https://builds.apache.org/job/xmlgraphics-batik-maven/ xmlgraphics-batik-maven
# https://builds.apache.org/job/xmlgraphics-batik-maven-mac/ xmlgraphics-batik-maven-mac
# https://builds.apache.org/job/xmlgraphics-commons/ xmlgraphics-commons
# https://builds.apache.org/job/xmlgraphics-commons-maven/ xmlgraphics-commons-maven
# https://builds.apache.org/job/xmlgraphics-fop/ xmlgraphics-fop
# https://builds.apache.org/job/xmlgraphics-fop-ant/ xmlgraphics-fop-ant
# https://builds.apache.org/job/xmlgraphics-fop-pdf-images/ xmlgraphics-fop-pdf-images
# https://builds.apache.org/job/xmlgraphics-test/ xmlgraphics-test
# https://builds.apache.org/job/xmlschema-1.4-branch-jdk15/ xmlschema-1.4-branch-jdk15
# https://builds.apache.org/job/xmlschema-trunk/ xmlschema-trunk
# https://builds.apache.org/job/xmlschema-trunk-eclipse-support/ xmlschema-trunk-eclipse-support
# https://builds.apache.org/job/Yetus/ Yetus
# https://builds.apache.org/job/yetus-qbt/ yetus-qbt
# https://builds.apache.org/job/Zest(JavaEdition)-develop-java8-check/ Zest(JavaEdition)-develop-java8-check
# https://builds.apache.org/job/Zest(JavaEdition)-develop-java8-checkDists/ Zest(JavaEdition)-develop-java8-checkDists
# https://builds.apache.org/job/Zest(JavaEdition)-support-2.1-java7-check/ Zest(JavaEdition)-support-2.1-java7-check
# https://builds.apache.org/job/Zest(JavaEdition)-support-2.1-java7-checkDists/ Zest(JavaEdition)-support-2.1-java7-checkDists
# https://builds.apache.org/job/ZooKeeper-trunk/ ZooKeeper-trunk
# https://builds.apache.org/job/ZooKeeper-trunk-jdk8/ ZooKeeper-trunk-jdk8
# https://builds.apache.org/job/ZooKeeper-trunk-openjdk7/ ZooKeeper-trunk-openjdk7
# https://builds.apache.org/job/ZooKeeper-trunk-solaris/ ZooKeeper-trunk-solaris
# https://builds.apache.org/job/ZooKeeper-trunk-WinVS2008/ ZooKeeper-trunk-WinVS2008
# https://builds.apache.org/job/ZooKeeper-trunk-WinVS2008_java/ ZooKeeper-trunk-WinVS2008_java
# https://builds.apache.org/job/ZooKeeper_branch33/ ZooKeeper_branch33
# https://builds.apache.org/job/ZooKeeper_branch33_solaris/ ZooKeeper_branch33_solaris
# https://builds.apache.org/job/ZooKeeper_branch34/ ZooKeeper_branch34
# https://builds.apache.org/job/ZooKeeper_branch34-WinVS2008_java/ ZooKeeper_branch34-WinVS2008_java
# https://builds.apache.org/job/ZooKeeper_branch34_jdk7/ ZooKeeper_branch34_jdk7
# https://builds.apache.org/job/ZooKeeper_branch34_jdk8/ ZooKeeper_branch34_jdk8
# https://builds.apache.org/job/ZooKeeper_branch34_openjdk7/ ZooKeeper_branch34_openjdk7
# https://builds.apache.org/job/ZooKeeper_branch34_solaris/ ZooKeeper_branch34_solaris
# https://builds.apache.org/job/ZooKeeper_branch35_jdk7/ ZooKeeper_branch35_jdk7
# https://builds.apache.org/job/ZooKeeper_branch35_jdk8/ ZooKeeper_branch35_jdk8
# https://builds.apache.org/job/ZooKeeper_branch35_openjdk7/ ZooKeeper_branch35_openjdk7
# https://builds.apache.org/job/ZooKeeper_branch35_solaris/ ZooKeeper_branch35_solaris

# %%
### Section 4:
### ==========

"""
Print all the jobs using the method get_jobs(), found in the 
class Jenkins() that's part of 'jenkins.py' in the jenkinsapi module.

On the info[1], which is reference to the various methods in the class Job 
that's part of the job.py in the jenkinsapi module, it is possible to obtain
details about the builds that belong to that particular job name.
"""

print(jenJob.get_jobs())
# Out:
# <generator object get_jobs at 0x04703530>

# %%
"""
Functions using the yield keyword are called generators.
In Section 4, jenjob.get_jobs() is a generator.
It can be iterated using a for-in loop or .next()
"""
print(jenJob.get_jobs().next())
print(jenJob.get_jobs().next())
print(jenJob.get_jobs().next())
# Out:
# ('Abdera-trunk', <jenkinsapi.job.Job Abdera-trunk>)
# ('Abdera-trunk', <jenkinsapi.job.Job Abdera-trunk>)
# ('Abdera-trunk', <jenkinsapi.job.Job Abdera-trunk>)

# %%
for info in jenJob.get_jobs():
    print(info[0])
# Out:
# Abdera-trunk
# Abdera2-trunk
# Accumulo-1.6
# Accumulo-1.7
# Accumulo-1.8
# Accumulo-Master
# Accumulo-Pull-Requests
# ACE-trunk
# ActiveMQ Protocol Buffer
# ActiveMQ-Apollo
# ActiveMQ-Apollo-Deploy
# ActiveMQ-Artemis-Deploy
# ActiveMQ-Artemis-Master
# ActiveMQ-Artemis-Nightly-Regression-Test
# ActiveMQ-Artemis-PR-Build
# ActiveMQ-Java7
# ActiveMQ-Java7-All-UnitTests
# ActiveMQ-Java8
# ActiveMQ-LevelDB-Store
# ActiveMQ-openwire
# ActiveMQ-PR-Build
# ActiveMQ-SysTest-Trunk
# ActiveMQ-Trunk-Deploy
# Airavata
# Allura
# Allura-rat
# Ambari-branch-1.7.0
# Ambari-branch-1.7.0-docker
# Ambari-branch-2.0.0
# Ambari-branch-2.1
# Ambari-branch-2.2
# Ambari-trunk-Commit
# Ambari-trunk-Commit-debug
# Ambari-trunk-Commit-docker
# Ambari-trunk-find-patches-available
# Ambari-trunk-test-patch
# Ambari-view
# Ant-Build-Matrix-1.9.x
# Ant-Build-Matrix-master
# ant-on-openjdk8
# Ant_BuildFromPOMs
# Ant_Nightly
# AntLib-antunit
# AntLib-common
# AntLib-compress
# AntLib-props
# AntLib-svn
# Any23-trunk
# Apache Jackrabbit Oak Documentation
# Apache Jackrabbit Oak matrix
# apache-atlas-nightly
# apache-deltacloud-core
# Apache-falcon
# Apache-Falcon-Distributed-Assembly
# apache-falcon-nightly
# apache-falcon-nightly-hadoop-2
# apache-falcon-patch-build
# Apache-Falcon-Pull-Request-Build
# archiva-1.3.x
# archiva-all-maven-3.x-with-web-it-js-windows
# archiva-master-build
# archiva-master-build-pr-builder
# archiva-master-empty-repo
# archiva-master-jdk-1.8
# archiva-master-web-it-js
# archiva-parent
# archivW
# Aries-Async-Deploy
# Aries-Blueprint-JDK7
# Aries-Deploy
# Aries-JPA-Trunk-JDK7
# Aries-JPA-Trunk-JDK7-Deploy
# Aries-rsa master
# Aries-rsa master deploy
# Aries-Transaction-Trunk-JDK7
# Aries-Trunk-JDK17
# Aries-Tx-Control-Deploy
# Aries-Tx-Control-Trunk-JDK8
# AriesWithSnapshotDependencies
# ASF Parent Pom
# AsyncWeb
# Aurora
# aurora-packaging-nightly
# AuroraBot
# AVRO-python
# AvroJava
# AWF
# axiom-1.2.x
# axiom-experimental
# axiom-trunk
# axis-trunk
# Axis2
# axis2-1.6
# axis2-1.7
# batchee
# beam_PostCommit_MavenVerify
# beam_PostCommit_MavenVerify_NEW
# beam_PostCommit_RunnableOnService_GoogleCloudDataflow
# beam_PreCommit_MavenVerify
# beam_PreCommit_RunnableOnService_GoogleCloudDataflow
# beam_Release_NightlySnapshot
# beam_Release_Prepare
# beam_testing
# Bigtop-Patch-Evaluate
# Bigtop-tickle-slaves
# Bigtop-trunk
# Bigtop-trunk-iTest
# Bigtop-trunk-test-execution
# Bigtop-trunk-testartifacts
# Blur-master-jdk8
# bookkeeper-debug
# bookkeeper-master
# bookkeeper-master-find-patches-available
# bookkeeper-master-git-pullrequest
# bookkeeper-trunk-precommit-build
# brooklyn-client-master
# brooklyn-client-pull-requests
# brooklyn-dist-master
# brooklyn-dist-pull-requests
# brooklyn-library-master
# brooklyn-library-pull-requests
# brooklyn-master-build
# brooklyn-master-integration
# brooklyn-master-windows
# brooklyn-server-master
# brooklyn-server-pull-requests
# brooklyn-ui-master
# brooklyn-ui-pull-requests
# build-incubator-atlas
# Buildr-ci-build-jruby-win32
# BVal-trunk
# BVal-trunk-linux-tck-deploy
# Cactus
# Calcite-Avatica-Master-JDK-1.7
# Calcite-Avatica-Master-JDK-1.8
# Calcite-Avatica-Test-JDK-1.7
# Calcite-Master-JDK-1.7
# Calcite-Master-JDK-1.8
# Camel.2.15.x.fulltest
# Camel.2.15.x.notest
# Camel.2.16.x.fulltest
# Camel.2.16.x.notest
# Camel.2.17.x.fulltest
# Camel.2.17.x.notest
# Camel.trunk.fulltest.java8
# Camel.trunk.itest.karaf
# Camel.trunk.itest.osgi
# Camel.trunk.notest
# Cayenne pull requests
# cayenne-30
# cayenne-31
# cayenne-master
# central-indexer-test
# Chemistry - DotCMIS
# Chemistry - OpenCMIS - install - Java 6
# Chemistry - OpenCMIS - install - Java 7
# Chemistry - OpenCMIS - install - Java 8
# Chemistry - OpenCMIS - javadoc
# Chemistry - OpenCMIS - Release Profile
# Chemistry - OpenCMIS - Workbench
# Chemistry-Phyton-cmislib-doc
# Chukwa-master
# clerezza
# clerezza-rdf-core
# clerezza-scala-1.6
# clerezza-site
# climate_master_build
# cloudstack-apidocs-master
# cloudstack-marvin
# cloudstack-master-maven
# cloudstack-pr-analysis
# cloudstack-rat-master
# cloudstack-simulator-master
# cloudstack-simulator-singlerun
# Cocoon 2.1.X
# Cocoon 2.2
# Cocoon 3.0
# CODI (add-ons)
# CODI (deploy)
# CODI (nightly)
# CODI (nightly) -j ava8arm
# codi-apache-extras
# codi-apache-extras-addons
# codi-apache-extras-test
# codi-mirror
# CODI-test
# CODI-u1test
# Commons Math DeveloperBranch
# Commons Math MasterBranch
# Commons Test - do not use
# Commons-Codec
# commons-collections
# Commons-Compress
# Commons-Compress-Windows
# Commons-configuration
# Commons-CRYPTO-JDK1.6
# Commons-CRYPTO-JDK1.7
# Commons-CRYPTO-JDK1.8
# commons-csv
# Commons-FileUpload
# commons-jcs
# Commons-Lang
# Commons-ognl
# commons-vfs-trunk
# CommonsAdHoc
# CommonsAnt
# cordova-nightly
# cordova-nightly-test
# core-integration-testing-maven-3
# core-integration-testing-maven-3-embedded
# core-integration-testing-maven-3-jdk-1.6-windows
# core-integration-testing-maven-3-jdk-1.7
# core-integration-testing-maven-3-jdk-1.8
# core-integration-testing-maven-3-osx
# core-integration-testing-maven-3-solaris
# core-it-maven-3-win
# CouchDB
# Creadur-Rat
# Creadur-Rat-Latest-Jdk
# Creadur-Rat-ParentPom
# Creadur-Rat-Site
# Creadur-Rat-Site-Latest-Jdk
# Creadur-Tentacles
# Creadur-Tentacles-Site
# Creadur-Whisker
# Creadur-Whisker-Latest-Jdk
# Creadur-Whisker-ParentPom
# Creadur-Whisker-Site
# Creadur-Whisker-Site-Latest-Jdk
# crunch-commit
# crunch-integration
# crunch-master
# ctakes-trunk-compiletest
# ctakes-trunk-package
# Curator
# Curator-3.0
# CXF-2.7-deploy
# CXF-2.7.x
# CXF-3.0-deploy
# CXF-3.0.x
# CXF-3.1-deploy
# CXF-3.1.x
# CXF-build-tools
# CXF-DOSGi
# CXF-DOSGi-deploy
# CXF-Fediz
# CXF-Fediz-1.2.x-fixes
# CXF-Fediz-openjdk17
# CXF-trunk-deploy
# CXF-Trunk-JDK18
# CXF-Trunk-PR
# CXF-trunk-windows
# CXF-xjc-utils
# DeltaSpike Deploy
# DeltaSpike Examples
# DeltaSpike for CDI 1.0
# DeltaSpike for CDI 1.1 and 1.2
# DeltaSpike for CDI 2.0
# DeltaSpike for Java EE
# DeltaSpike OWB (nightly)
# DeltaSpike OWB 1.1.1
# DeltaSpike OWB 1.1.2
# DeltaSpike OWB 1.1.3
# DeltaSpike OWB 1.1.4
# DeltaSpike OWB 1.1.5
# DeltaSpike OWB 1.1.6
# DeltaSpike OWB 1.1.6 (JDK 1.7)
# DeltaSpike OWB 1.1.7
# DeltaSpike OWB 1.1.8
# Deltaspike OWB 1.1.9-SNAPSHOT
# DeltaSpike OWB 1.2.0
# DeltaSpike OWB 1.2.1
# DeltaSpike OWB 1.2.1 java8_ARM
# DeltaSpike OWB 1.2.2
# DeltaSpike OWB 1.2.3
# DeltaSpike OWB 1.2.4
# DeltaSpike OWB 1.2.5
# DeltaSpike OWB 1.2.6
# DeltaSpike OWB 1.2.7
# DeltaSpike OWB 1.6.0
# DeltaSpike OWB 1.6.1
# DeltaSpike OWB 1.6.2
# DeltaSpike OWB JDK8
# DeltaSpike OWB OpenJDK8
# DeltaSpike RAT-Check
# DeltaSpike Weld (nightly)
# DeltaSpike Weld 1.1.10
# DeltaSpike Weld 1.1.11
# DeltaSpike Weld 1.1.12
# DeltaSpike Weld 1.1.13
# DeltaSpike Weld 1.1.14
# DeltaSpike Weld 1.1.15
# DeltaSpike Weld 1.1.16
# DeltaSpike Weld 1.1.17
# DeltaSpike Weld 1.1.18
# DeltaSpike Weld 1.1.19
# DeltaSpike Weld 1.1.19 (JDK 1.7)
# DeltaSpike Weld 1.1.20
# DeltaSpike Weld 1.1.21
# DeltaSpike Weld 1.1.22
# DeltaSpike Weld 1.1.23
# DeltaSpike Weld 1.1.24
# DeltaSpike Weld 1.1.25
# DeltaSpike Weld 1.1.26
# DeltaSpike Weld 1.1.27
# DeltaSpike Weld 1.1.28
# DeltaSpike Weld 1.1.29
# DeltaSpike Weld 1.1.3
# DeltaSpike Weld 1.1.3.SP1
# DeltaSpike Weld 1.1.30
# DeltaSpike Weld 1.1.31
# DeltaSpike Weld 1.1.32
# DeltaSpike Weld 1.1.33
# DeltaSpike Weld 1.1.4
# DeltaSpike Weld 1.1.5
# DeltaSpike Weld 1.1.5.AS71
# DeltaSpike Weld 1.1.6
# DeltaSpike Weld 1.1.7
# DeltaSpike Weld 1.1.8
# DeltaSpike Weld 1.1.9
# DeltaSpike Weld 2.0.0
# DeltaSpike Weld 2.0.0.SP1
# DeltaSpike Weld 2.0.1
# DeltaSpike Weld 2.0.2
# DeltaSpike Weld 2.0.3
# DeltaSpike Weld 2.0.4
# DeltaSpike Weld 2.0.5
# DeltaSpike Weld 2.1.0
# DeltaSpike Weld 2.1.1
# DeltaSpike Weld 2.1.2
# DeltaSpike Weld 2.2.0
# DeltaSpike Weld 2.2.1
# DeltaSpike Weld 2.2.10
# DeltaSpike Weld 2.2.10.SP1
# DeltaSpike Weld 2.2.11
# DeltaSpike Weld 2.2.12
# DeltaSpike Weld 2.2.13
# DeltaSpike Weld 2.2.14
# DeltaSpike Weld 2.2.15
# DeltaSpike Weld 2.2.16
# DeltaSpike Weld 2.2.16.SP1
# DeltaSpike Weld 2.2.2
# DeltaSpike Weld 2.2.3
# DeltaSpike Weld 2.2.4
# DeltaSpike Weld 2.2.5
# DeltaSpike Weld 2.2.6
# DeltaSpike Weld 2.2.7
# DeltaSpike Weld 2.2.8
# DeltaSpike Weld 2.2.9
# DeltaSpike Weld 2.3.0
# DeltaSpike Weld 2.3.1
# DeltaSpike Weld 2.3.2
# DeltaSpike Weld 2.3.3
# DeltaSpike Weld 2.3.4
# DeltaSpike Weld 3.0.0 Alpha 14
# DeltaSpike_AS7
# DeltaSpike_GF3
# DeltaSpike_GF4
# DeltaSpike_GF4.1
# DeltaSpike_GF4.1.1
# DeltaSpike_TomEE
# DeltaSpike_TomEE-SNAPSHOT
# DeltaSpike_TomEE_1.6.0
# DeltaSpike_TomEE_1.7.0
# DeltaSpike_TomEE_1.7.1
# DeltaSpike_TomEE_1.7.2
# DeltaSpike_TomEE_1.7.3
# DeltaSpike_TomEE_7.0.0-M3
# DeltaSpike_Wildfly
# DeltaSpike_Wildfly_10
# DeltaSpike_Wildfly_8.1
# DeltaSpike_Wildfly_8.2
# DeltaSpike_Wildfly_8.2.1
# DeltaSpike_Wildfly_9.0
# DeltaSpike_Wildfly_9.0.1
# DeltaSpike_Wildfly_9.0.2
# Derby-10.10-derbyall
# Derby-10.10-suites.All
# Derby-10.11-derbyall
# Derby-10.11-suites.All
# Derby-10.12-suites.All
# Derby-10.9-derbyall
# Derby-10.9-suites.All
# Derby-branch-10.10
# Derby-branch-10.11
# Derby-branch-10.12
# Derby-branch-10.5
# Derby-branch-10.6
# Derby-branch-10.7
# Derby-branch-10.8
# Derby-branch-10.9
# Derby-docs
# Derby-JaCoCo
# Derby-trunk
# Derby-trunk-JaCoCo
# Derby-trunk-suites.All
# Derby-trunk-suites.All-ARM
# devicemap-browsermap
# devicemap-data-1.0
# devicemap-java-client-1.0
# dir-apacheds-docker-installers
# dir-apacheds-jdbm-ubuntu-deploy
# dir-apacheds-jdbm-win
# dir-apacheds-ubuntu-deploy
# dir-apacheds-win
# dir-checkstyle-deploy
# dir-fortress-core-docker-test
# dir-groovyldap-deploy
# dir-junit-addons-deploy
# dir-kerby
# dir-kerby-openjdk
# dir-mavibot-ubuntu-deploy
# dir-mavibot-win
# dir-project-deploy
# dir-shared-ubuntu-deploy
# dir-shared-win
# dir-skins-deploy
# dir-studio
# dir-studio-ui-tests
# dist-tool-plugin
# doxia
# doxia-all
# doxia-eclipse-editor
# doxia-sitetools
# doxia-tools
# Drill - Prototype - build
# Drill-Physical-Plan
# drill-scm
# EasyAnt
# Empire-db multios
# Empire-db reports
# Empire-db snapshot
# Environment check
# ESME
# etch-trunk-linux-x86
# etch-trunk-linux-x86-experimental
# etch-trunk-windows-x86
# etch-trunk-windows-x86-experimental
# ExtVal for JSF 1.2 (deploy)
# ExtVal for JSF 1.2 (nightly)
# ExtVal for JSF 2.0 (deploy)
# ExtVal for JSF 2.0 (nightly)
# Felix iPOJO API
# Felix iPOJO Arch
# Felix iPOJO Arch-Gogo
# Felix iPOJO EventAdmin Handler
# Felix iPOJO Extender Handler
# Felix iPOJO JMX Handler
# Felix iPOJO Junit4OSGi
# Felix iPOJO Manipulator
# Felix iPOJO Metadata
# Felix iPOJO Runtime
# Felix iPOJO Temporal Handler
# Felix iPOJO Tests
# Felix iPOJO Transaction Handler
# Felix iPOJO Webconsole
# Felix iPOJO Whiteboard Handler
# Felix-FileInstall
# Felix-Gogo
# Felix-WebConsole
# flex-asjs
# flex-asjs (maven)
# flex-blazeds
# flex-falcon
# flex-falcon (maven)
# flex-flexunit
# flex-pmd
# flex-productdashboard
# flex-sdk
# flex-sdk-converter
# flex-sdk_pixelbender
# flex-sdk_release
# flex-tlf
# flex-tool-api
# flink-ci
# flink-snapshot-deployment
# flume-0.9
# flume-1.3.0
# flume-1.4.0
# Flume-1.6-HBase-98
# flume-trunk
# Flume-trunk-hbase-1
# FontBox-trunk
# ftpserver-1.0.x-jdk1.5-solaris
# ftpserver-1.0.x-jdk1.5-ubuntu
# ftpserver-trunk-jdk1.5-ibm-ubuntu
# ftpserver-trunk-jdk1.5-solaris
# ftpserver-trunk-jdk1.5-ubuntu
# ftpserver-trunk-jdk1.6-freebsd
# ftpserver-trunk-jdk1.6-ibm-ubuntu
# ftpserver-trunk-jdk1.6-osx
# ftpserver-trunk-jdk1.6-solaris
# ftpserver-trunk-jdk1.6-ubuntu
# ftpserver-trunk-jdk1.6-windows
# gcc-test-vinod
# Geode-nightly
# Geode-nightly-copy
# Geode-release
# Geode-spark-connector
# Geode-trunk-test-patch
# Geronimo Spec JMS 2.0
# Geronimo-Specs-trunk
# Giraph-1.1
# Giraph-1.1.0-old
# Giraph-trunk-Commit
# Giraph-trunk-default-deploy
# giraph-trunk-hadoop-0.20.203
# giraph-trunk-hadoop-0.23
# giraph-trunk-hadoop-1.0
# giraph-trunk-hadoop-trunk
# Giraph-trunk-hadoop2-deploy
# giraph-trunk-non-secure
# Giraph-trunk-site
# gora-trunk
# Groovy Github PRs
# Groovy Pull Requests Matrix Job
# Groovy Ubuntu
# Groovy Windows
# Hadoop-ATS-v2
# Hadoop-branch2
# Hadoop-branch2-parameterized
# Hadoop-Common-2-Build
# Hadoop-Common-2-Commit
# Hadoop-Common-trunk
# Hadoop-common-trunk-Java8
# Hadoop-Common-trunk-win
# Hadoop-fs-encryption-nightly
# Hadoop-Hdfs-7966
# Hadoop-HDFS-8833
# Hadoop-HDFS-8909
# Hadoop-Hdfs-HAbranch-build
# Hadoop-Hdfs-NIFbranch-build
# Hadoop-Hdfs-trunk
# Hadoop-Hdfs-trunk-Commit
# Hadoop-Hdfs-trunk-Java8
# Hadoop-Hdfs-trunk-win
# Hadoop-integration-tests
# Hadoop-Mapreduce-trunk
# Hadoop-Mapreduce-trunk-Commit
# Hadoop-Mapreduce-trunk-Java8
# Hadoop-Mapreduce-trunk-win
# hadoop-qbt
# hadoop-qbt-test
# Hadoop-trunk
# Hadoop-trunk-ARM
# Hadoop-trunk-Commit
# hadoop-trunk-osx-java8
# hadoop-trunk-solaris-java8
# hadoop-trunk-win-java8
# hadoop-win1
# Hadoop-Yarn-trunk
# Hadoop-Yarn-trunk-Java8
# HADOOP2_Release_Artifacts_Builder
# Hama-Nightly-for-Hadoop-1.x
# Hama-Nightly-for-Hadoop-2.x
# Hama-trunk
# HAWQ Downloads
# HAWQ SCM Build
# HAWQ-build-pullrequest
# HAWQ-libhdfs-nightly
# HAWQ-libyarn-nightly
# HAWQ-nightly
# HBase Website Link Ckecker
# HBase-0.94
# HBase-0.94-JDK7
# HBase-0.94-on-Hadoop-2
# HBase-0.94-security
# HBase-0.94.18-security
# HBase-0.94.28
# HBase-0.98
# HBase-0.98-matrix
# HBase-0.98-on-Hadoop-1.1
# HBase-1.0
# HBase-1.1
# HBase-1.1-JDK7
# HBase-1.1-JDK8
# HBase-1.2
# HBase-1.2 non-matrix
# HBase-1.2-IT
# HBase-1.3
# HBase-1.3-IT
# HBase-1.4
# HBase-Find-Flaky-Tests
# HBase-Flaky-Tests
# hbase-qbt-test
# HBase-TRUNK
# HBase-Trunk-IT
# HBase-Trunk_matrix
# hbase_generate_website
# HDT-hadoop-eclipse-merge
# helix
# helix-1.7
# Hive-0.14
# Hive-trunk
# HTrace-Master
# httpcomponents-asyncclient-4.1.x
# httpcomponents-asyncclient-trunk
# httpcomponents-client-4.5.x
# httpcomponents-client-5.x
# httpcomponents-core-4.4.x
# httpcomponents-core-5.x
# hupa-trunk
# hupa-trunk-site
# Ignite-artifacts
# Ignite-nightly
# imap-trunk-m2
# imap-trunk-site
# incubator-brooklyn-master-build
# incubator-brooklyn-master-integration
# incubator-brooklyn-master-windows
# incubator-brooklyn-pull-requests
# incubator-commonsrdf
# incubator-eagle-main
# incubator-eagle-pr-reviewer
# incubator-eagle-test
# incubator-rya-develop
# incubator-taverna-commandline
# incubator-taverna-commandline-nightly
# incubator-taverna-common-activities
# incubator-taverna-engine
# incubator-taverna-language
# incubator-taverna-language-pull-requests
# incubator-taverna-maven-parent
# incubator-taverna-osgi
# incubator-taverna-plugin-bioinformatics
# incubator-taverna-plugin-component
# incubator-taverna-server
# incubator-taverna-workbench
# incubator-taverna-workbench-common-activities
# incubator-taverna-workbench-product
# isis-core-ubuntu
# Ivy
# Ivy-check
# Ivy-tests
# IvyDE
# IvyDE-updatesite
# Jackrabbit Oak trunk with JR SNAPSHOT
# Jackrabbit-2.2
# Jackrabbit-trunk
# Jakarta_BSF3
# james-mailet
# james-project
# james-server-trunk
# james-server-trunk-site
# james-server-v2.3
# james-server-v2.3-m2
# james-skin
# jclouds-labs-google-pull-request-test
# jdkim-trunk
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-d158ff5eb889> in <module>()
# ----> 1 for info in jenJob.get_jobs():
#       2     print(info[0])
#
# C:\Python27\lib\site-packages\jenkinsapi\jenkins.pyc in get_jobs(self)
#     114         for info in jobs:
#     115             yield info["name"], \
# --> 116                 Job(info["url"], info["name"], jenkins_obj=self)
#     117
#     118     def get_jobs_info(self):
#
# C:\Python27\lib\site-packages\jenkinsapi\job.pyc in __init__(self, url, name, jenkins_obj)
#      71             None: lambda element_tree: []
#      72         }
# ---> 73         JenkinsBase.__init__(self, url)
#      74
#      75     def __str__(self):
#
# C:\Python27\lib\site-packages\jenkinsapi\jenkinsbase.pyc in __init__(self, baseurl, poll)
#      33         self.baseurl = self.strip_trailing_slash(baseurl)
#      34         if poll:
# ---> 35             self.poll()
#      36
#      37     def get_jenkins_obj(self):
#
# C:\Python27\lib\site-packages\jenkinsapi\job.pyc in poll(self, tree)
#      95
#      96     def poll(self, tree=None):
# ---> 97         data = super(Job, self).poll(tree=tree)
#      98         if not tree:
#      99             self._data = self._add_missing_builds(self._data)
#
# C:\Python27\lib\site-packages\jenkinsapi\jenkinsbase.pyc in poll(self, tree)
#      57
#      58     def poll(self, tree=None):
# ---> 59         data = self._poll(tree=tree)
#      60         if 'jobs' in data:
#      61             data['jobs'] = self.resolve_job_folders(data['jobs'])
#
# C:\Python27\lib\site-packages\jenkinsapi\jenkinsbase.pyc in _poll(self, tree)
#      67     def _poll(self, tree=None):
#      68         url = self.python_api_url(self.baseurl)
# ---> 69         return self.get_data(url, tree=tree)
#      70
#      71     def get_data(self, url, params=None, tree=None):
#
# C:\Python27\lib\site-packages\jenkinsapi\jenkinsbase.pyc in get_data(self, url, params, tree)
#      77                 params.update({'tree': tree})
#      78
# ---> 79         response = requester.get_url(url, params)
#      80         if response.status_code != 200:
#      81             logging.error('Failed request at %s with params: %s %s',
#
# C:\Python27\lib\site-packages\jenkinsapi\utils\requester.pyc in get_url(self, url, params, headers, allow_redirects)
#      98             headers=headers,
#      99             allow_redirects=allow_redirects)
# --> 100         return requests.get(self._update_url_scheme(url), **requestKwargs)
#     101
#     102     def post_url(self, url, params=None, data=None, files=None,
#
# C:\Python27\lib\site-packages\requests\api.pyc in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# C:\Python27\lib\site-packages\requests\api.pyc in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# C:\Python27\lib\site-packages\requests\sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# C:\Python27\lib\site-packages\requests\sessions.pyc in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# C:\Python27\lib\site-packages\requests\adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     374                     decode_content=False,
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#     378
#
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     557             httplib_response = self._make_request(conn, method, url,
#     558                                                   timeout=timeout_obj,
# --> 559                                                   body=body, headers=headers)
#     560
#     561             # If we're going to release the connection in ``finally:``, then
#
# C:\Python27\lib\site-packages\requests\packages\urllib3\connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     374         try:
#     375             try:  # Python 2.7, use buffering of HTTP responses
# --> 376                 httplib_response = conn.getresponse(buffering=True)
#     377             except TypeError:  # Python 2.6 and older
#     378                 httplib_response = conn.getresponse()
#
# C:\Python27\lib\httplib.pyc in getresponse(self, buffering)
#    1130
#    1131         try:
# -> 1132             response.begin()
#    1133             assert response.will_close != _UNKNOWN
#    1134             self.__state = _CS_IDLE
#
# C:\Python27\lib\httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# C:\Python27\lib\httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# C:\Python27\lib\socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# C:\Python27\lib\ssl.pyc in recv(self, buflen, flags)
#     732                     "non-zero flags not allowed in calls to recv() on %s" %
#     733                     self.__class__)
# --> 734             return self.read(buflen)
#     735         else:
#     736             return self._sock.recv(buflen, flags)
#
# C:\Python27\lib\ssl.pyc in read(self, len, buffer)
#     619                 v = self._sslobj.read(len, buffer)
#     620             else:
# --> 621                 v = self._sslobj.read(len or 1024)
#     622             return v
#     623         except SSLError as x:
#
# KeyboardInterrupt:
